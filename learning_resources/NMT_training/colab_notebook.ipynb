# %% [markdown]
# <a href="https://colab.research.google.com/github/ITMK/DataLitMT/blob/main/colab_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![KeyVisual_DataLitMT - Kopie.jpg](data:image/jpeg;base64,...)
#
# # Data Processing: NMT Training Notebook – Advanced Level
# **How to train an NMT model from scratch**

# %% [markdown]
# **NOTE: Training an NMT model takes a long time. We advise that you only work through this notebook if you have about TWO HOURS of time to spare.** This is already a very short training time and can only be achieved when training a rather small model. Big NMT models are usually trained over a number of days.

# %% [markdown]
# This Colab Notebook covers the sub-dimensions of *Data Processing* (and, to some extent, *Data Creation*) of the [DataLit<sup>MT</sup> Competence Matrix](https://itmk.github.io/The-DataLitMT-Project/matrix/). This notebook guides you step-by-step through accessing previously prepared data to train a neural machine translation (NMT) model using the [OpenNMT-py toolkit](https://opennmt.net/). Training an NMT model is part of *Technical MT Literacy*, as illustrated in the [Professional Machine Translation Literacy Framework](https://itmk.github.io/The-DataLitMT-Project/framework/#professional-mt-literacy). In this notebook, we use the *Transformer* architecture, which was proposed by [Vaswani et al. (2017)](https://papers.nips.cc/paper/2017/hash/3f5ee243547dee91fbd053c1c4a845aa-Abstract.html)). The Transformer has become not only the standard architecture for high-performing NMT systems, but also for large language models such as [Google's BERT](https://ai.googleblog.com/2018/11/open-sourcing-bert-state-of-art-pre.html) or [OpenAI's GPT models](https://openai.com/api/). If you would like to know more about how the Transformer architecture works, check out Jay Alammar's excellent article on [The Illustrated Transformer](https://jalammar.github.io/illustrated-transformer/).
#
# Note: Before you work through this notebook, we recommend that you complete the Data Planning and Collection (data preparation) task first, either at [Basic Level](https://colab.research.google.com/drive/17aCfPF0Zw80gW0FYg_iRo16YVSMAaNKG?usp=sharing) or at [Advanced Level](https://colab.research.google.com/drive/1ls2DIKkD8B2FgkIEYZVjqpAVcr5IZMRa?usp=sharing) and to *save* the datasets created in this task in your Google Drive folder. If you would like to skip this step and start training your NMT model right away, check the *Accessing Data* step below.
#
# **General Information**
# There are a number of open-source frameworks for training an NMT model from scratch, such as [JoeyNMT](https://joeynmt.readthedocs.io/en/latest/) or OpenNMT-py. A comprehensive list of frameworks and pre-trained models can be found, for example, on [Hugging Face](https://huggingface.co/). The code used in this notebook is provided by OpenNMT-py. While it may seem quite complex at first, implementing this code and adjusting relevant parameters is actually rather straightforward. All steps performed in this notebook will be described in detail both here in this notebook and in the accompanying tutorial video. We recommend that you watch the video to get a good overview and a thorough understanding of the process of training an NMT model from scratch.
#
# **Steps to take**
# For this MT project scenario, we chose the English-German parallel dataset TED2020, with English being the source and German the target language, as illustrated in our [Basic](https://colab.research.google.com/drive/17aCfPF0Zw80gW0FYg_iRo16YVSMAaNKG?usp=sharing) and [Advanced](https://colab.research.google.com/drive/1ls2DIKkD8B2FgkIEYZVjqpAVcr5IZMRa?usp=sharing) notebooks on Data Planning and Data Collection. As mentioned above, completing one of the the Data Preparation notebooks is a recommended preparatory step for the present notebook, since it will give you a good understanding of how we arrived at the training data to be used in the present notebook. In the Data Preparation notebook, we guide you through downloading the required NMT training data, preparing (cleaned and filtered) and subwording this data, and splitting it into three sub-datasets (training, development and test), which are needed for NMT training. In the present notebook, you will learn how to train an NMT engine from scratch using your three sub-datasets and how to use your NMT model to translate texts. Here, we will use English as the source and German as the target language, but you could also use your dataset to train a German-English NMT model. Of course, if you have a different dataset at hand and know how to access it and implement it here, you are welcome to train an NMT model using this dataset instead.

# %% [markdown]
# ### Optional – Accessing Data
#
# If you did not complete the previous task on Data Preparation and would like to start training your own NMT model right away, you can access and download all data required for this notebook on our GitHub repository [here](https://github.com/ITMK/DataLitMT/tree/main/learning_resources/NMT_Training) (the file is called *TED data.zip*). This zip file contains all datasets required for training an NMT in this notebook as well as the subword models needed for desubwording texts translated with our model (described at the end of notebook). Unzip the file and save the data (without re-naming the files) in a folder on your Google Drive. Then you can refer to this Drive folder in this notebook and follow the code. This step is also shown in the tutorial video.

# %% [markdown]
# # 0 Housekeeping
#
# For this notebook, it is required that you **change your runtime to GPU**. All Colab Notebooks run on CPU by default. Since we'll be needing more computing power to train an NMT model than can be provided by a CPU, we use the more powerful GPU which Google Colab provides for such use cases.
# To switch from CPU to GPU, go to "runtime", and then --> "change runtime". For "hardware accelerator" select GPU.

# %% [markdown]
# ## Installing OpenNMT-py
#
# First, you need to install the OpenNMT-py package – the most recent version is version 3.0. Simply run the following cell to do so. OpenNMT requires Python 3.7 or above (which should be installed in this Colab environment). For more information on [OpenNMT-py](https://opennmt.net/OpenNMT-py/) and how to use it, have a look at their [GitHub](https://github.com/OpenNMT/OpenNMT-py) or check out the [official documentation](https://opennmt.net/OpenNMT-py/) or the [forum](https://forum.opennmt.net/).

# %%
# !pip3 install OpenNMT-py

# %% [markdown]
# ## Connecting to Google Drive to Access Datasets
#
# Next, you will need to connect this notebook to your Google Drive account in order to then access the datasets that you have previously prepared and saved. To connect this notebook to Google Drive, run the cell below. You will need to select and confirm your Google Account. This step is also shown in the tutorial video.
#
# If connecting to Google Drive was successful, the cell below will output “Drive Mounted”  or a similar message.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# The following step is **important** and you **actively need to change the line of code in the code cell below** to access the folder in your Google Drive where you have previously saved the datasets from the Data Planning and Collection task. In the code below, replace the string "YOUR_FOLDER_NAME" (likely called *MT_data_preparation* from the data preparation task) with the folder that contains your datasets.
#
# If you have done so, run the cell below in order to change the current directory to that folder. This means that you can directly access the data saved in that folder throughout this notebook and you can also save new data directly to that folder. The code cell below will also list the content of your folder. This way, you can make sure that you are actually connected to the correct folder.
#
# Your folder should contain the following datasets from the Data Preparation task (the files should be listed after running the cell below):
#
# *   `TED2020.de-en.de-filtered.de.subword.dev`
# *   `TED2020.de-en.de-filtered.de.subword.test`
# *   `TED2020.de-en.de-filtered.de.subword.train`
# *   `TED2020.de-en.en-filtered.en.subword.dev`
# *   `TED2020.de-en.en-filtered.en.subword.test`
# *   `TED2020.de-en.en-filtered.en.subword.train`
#
# **Important:** For the following steps, your datasets must be named **exactly** as described here. If not, please re-name your datasets in your Google Drive folder to match the file names used in this notebook. The file names are rather long, but to make sure that the correct files are referred to, please do not rename them (unless you are confident to do so and know how to change the names in all relevant code cells in this notebook).

# %%
# %cd /content/drive/MyDrive/MT_data_preparation/
# !ls

# If you have saved your data in an 'MT_data_preparation' folder, the code line above would be: %cd /content/drive/MyDrive/MT_data_preparation
# Out:
# /content/drive/MyDrive/MT_data_preparation
# source.model
# target.model
# TED2020.de-en.de-filtered.de.subword.dev
# TED2020.de-en.de-filtered.de.subword.test
# TED2020.de-en.de-filtered.de.subword.train
# TED2020.de-en.en-filtered.en.subword.dev
# TED2020.de-en.en-filtered.en.subword.test
# TED2020.de-en.en-filtered.en.subword.train

# %% [markdown]
# # 1 Creating the Training Configuration File
#
# Before you work through this step, make sure that the previous steps have been completed and that you have connected this notebook to your Google Drive folder. The cell below is the first crucial step towards training an NMT model. It creates a configuration file that contains all information needed to train an NMT model. The cell below defines a Transformer NMT model and the code is provided by OpenNMT, as described above.
#
# It is **important** to note that the parameters used in the code cell below have been adjusted to allow for a quick NMT training. Parameters can be adjusted individually for NMT model training, very much depending on what the training focus should be. Have a look at the [OpenNMT-py training parameters](https://opennmt.net/OpenNMT-py/options/train.html) if you want to know more about the individual parameters. A list of (optional/extensive) parameters for the Tensorflow implementation OpenNMT-tf, many of which can also be used for the Python implementation OpenNMT-py, can be found [here](https://opennmt.net/OpenNMT-tf/configuration.html).

# %% [markdown]
# ## Parameters

# %% [markdown]
# Let's have a more detailed look at the parameters defined below. Please **do not** change anything in the code unless you are confident to do so. It is **not required** to change the code below at this point, you can simply run the cell as it is. We will, however, explain relevant aspects of these parameters here. Again, make sure that your datasets are named **exactly** as described above, since we refer to those datasets by their names in the code below.
#
# * `config.yaml` – The first line creates a configuration file in [yaml](https://yaml.org/spec/1.2.2/) format. It will be saved as *config.yaml* in your Drive folder. This file is needed for NMT training later, as it contains all the information required for defining and training your NMT model!
# * `save_data: run` – This indicates that the vocabulary data (created later) will be saved in a folder called *run* in your Drive folder.
# * `data` --> `corpus_1` --> `path_src:` –  Here, the path to the source training data in your Drive folder is defined.
# * `data` --> `corpus_1` --> `path_tgt:` – Here, the path to the target training data in your Drive folder is defined.
# * `data` --> `valid` --> `path_src:` – Here, the path to the source development (often also called validation) data in your Drive folder is defined.
# * `data` --> `valid` --> `path_tgt:` –  Here, the path to the target development data in your Drive folder is defined.
# * `source_vocab: run/source.vocab` – This indicates that the source vocabulary data (created later) will be saved in the *run* folder in your Drive folder.
# * `target_vocab: run/target.vocab` – This indicates that the target vocabulary data (created later) will be saved in the *run* folder in your Drive folder.
# * `source_vocab_size` and `target_vocab_size` – This parameter is set to **50k** words, meaning that we use a source and target vocabulary of 50,000 words each.
# * `tokenization options` – The input data could be tokenized, which is advised for NMT model training. This parameter refers to the subwording `source.model` and `target.model` that we created in the data preparation task.
# * `log_file: train.log` – At the end of the NMT training process, this *train.log* file will also be saved to your Drive folder. It logs all training steps and provides further information on model training.
# * `save_model: models/model.fren` – The NMT models trained here will be saved into a separate *models* folder in your Drive folder. They will automatically be named *model.fren_step_1000.pt* and so forth, for each training step. The **final** model (in this case *model.fren_step_4000.pt*, since we use 4,000 training steps as defined below) will then be used to translate the test dataset.
# * `save_checkpoint_steps` – This parameter defines how frequently a model is saved. We set it to **1000**, meaning that a model is saved every thousand steps.
# * `keep_checkpoint` – This defines how many of the saved checkpoints will be kept (the latest ones). Trained models take up quite some space, so model checkpoints saved in-between are not needed for final translation but can be kept as a backup or in case the training crashes before it ends. Here we keep 4 checkpoints (i.e., all checkpoints which are created in our training scenario).
# * `train_steps` – This defines the training steps for NMT model training. This value is usually set above 100,000 but for a quick tutorial using a small dataset (as in our notebook), we can set this value to **4000** – which will still result in an acceptable translation quality.
# * `valid_steps` – This parameter defines how frequently the training data is validated. For this step, the development dataset is used. Here we define validation to take place every **1000** steps. So, a total of four times in our scenario.
# * `gpu_ranks = [0]` – A GPU rank of [0] shows that 1 GPU is used (most programming languages start counting from 0). As mentioned above, a GPU (which provides more computing power than a CPU) is needed for NMT training.
# * `learning_rate` – This parameter is set to 1 here. 1 is a high value for the learning rate but allows for quicker training, as is our aim in this notebook.Change value for larger datasets and longer training times as specified below.
#
# -------------------------------------------------------------------------------
# Not necessary here, but recommended for **larger datasets** (with millions of sentences):
# * `source_vocab_size` and `target_vocab_size` – This parameter can be set to anywhere between 32k and 100k.
# * `train_steps` – 100k-200k or more
# * `valid_steps` – Can be 10,000 if the train steps are big enough
# * `warmup_steps` – Potentially 4000 or 8000
# * `save_checkpoint_steps` – (depends on how frequently you want to save checkpoints. Often same value as valid_steps, or more)
# * `keep_checkpoint` – (depends on how many saved checkpoints you want to keep – 10 or more)
# * `learning_rate` – For larger datasets and longer training times, change this value to as low as 0.0002. Otherwise, the model will learn fast but then stall or even drop back to zero in terms of accuracy.
#
# These parameters are discussed in a little more detail in the tutorial video.

# %% [markdown]
# ## Creating the Config File
#
# Without further ado, you can now run the cell below to create your `config.yaml` file and load it into your Google Drive folder.
#
# **NOTE: This step is only done once! If you have made a mistake, delete the created `config.yaml` file and run the cell again.**

# %%
# Create the config file

config = '''# config.yaml


## Where the samples will be written
save_data: run

# Training files
data:
    corpus_1:
        path_src: TED2020.de-en.en-filtered.en.subword.train
        path_tgt: TED2020.de-en.de-filtered.de.subword.train
        transforms: [filtertoolong]
    valid:
        path_src: TED2020.de-en.en-filtered.en.subword.dev
        path_tgt: TED2020.de-en.de-filtered.de.subword.dev
        transforms: [filtertoolong]

# Vocabulary files, generated by onmt_build_vocab
src_vocab: run/source.vocab
tgt_vocab: run/target.vocab

# Vocabulary size – should be the same as in SentencePiece
src_vocab_size: 50000
tgt_vocab_size: 50000

# Filter out source/target longer than n if [filtertoolong] enabled
src_seq_length: 150
src_seq_length: 150

# Tokenization options
src_subword_model: source.model
tgt_subword_model: target.model

# Where to save the log file and the output models/checkpoints
log_file: train.log
save_model: models/model.fren

# Stop training if it does not improve after n validations
early_stopping: 10

# Default: 5000 – Save a model checkpoint for each n
save_checkpoint_steps: 1000

# To save space, limit checkpoints to last n
keep_checkpoint: 4

seed: 3435

# Default: 100000 – Train the model to max n steps 
# Increase to 200000 or more for large datasets
# For fine-tuning, add up the required steps to the original steps
train_steps: 4000

# Default: 10000 – Run validation after n steps
valid_steps: 1000

# Default: 4000 – for large datasets, try up to 8000
warmup_steps: 1000
report_every: 100

# Number of GPUs, and IDs of GPUs
world_size: 1
gpu_ranks: [0]

# Batching
bucket_size: 262144
num_workers: 0  # Default: 2, set to 0 when RAM out of memory
batch_type: "tokens"
batch_size: 4096   # Tokens per batch, change when CUDA out of memory
valid_batch_size: 2048
max_generator_batches: 2
accum_count: [4]
accum_steps: [0]

# Optimization
model_dtype: "fp16"
optim: "adam"
learning_rate: 1 # 0.002
# warmup_steps: 8000
decay_method: "noam"
adam_beta2: 0.998
max_grad_norm: 0
label_smoothing: 0.1
param_init: 0
param_init_glorot: true
normalization: "tokens"

# Model
encoder_type: transformer
decoder_type: transformer
position_encoding: true
enc_layers: 6
dec_layers: 6
heads: 8
hidden_size: 512
word_vec_size: 512
transformer_ff: 2048
dropout_steps: [0]
dropout: [0.1]
attention_dropout: [0.1]
'''

with open("config.yaml", "w+") as config_yaml:
  config_yaml.write(config)

# %% [markdown]
# Run the cell below to have a look at your Google Drive folder and check whether a *config.yaml* file has indeed been created. It might take a few moments to load.

# %%
# Check the content of your folder
# !ls
# Out:
# config.yaml
# run
# source.model
# target.model
# TED2020.de-en.de-filtered.de.subword.dev
# TED2020.de-en.de-filtered.de.subword.test
# TED2020.de-en.de-filtered.de.subword.train
# TED2020.de-en.en-filtered.en.subword.dev
# TED2020.de-en.en-filtered.en.subword.test
# TED2020.de-en.en-filtered.en.subword.train

# %% [markdown]
# # Building the Vocabulary
#
# Running the following cell will create your vocabulary. This creates two vocabulary files in your *run* folder, one for the source data and one for the target data (each containing 50k words, as defined in our *config.yaml* file above). You need to make sure that your configuration file is actually saved in your Drive folder, because the following cell refers to this file (*config.yaml*). Simply run the cell below.
#
# **NOTE: This step is only done once! If you have made a mistake, delete the created *run* folder and the source and target vocabulary files and run the cell again.**

# %%
# Build your vocabulary
# !onmt_build_vocab -config config.yaml -n_sample -1 -num_threads 2
# Out:
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2023-02-16 08:46:11,818 INFO] Counter vocab from -1 samples.
# [2023-02-16 08:46:11,818 INFO] n_sample=-1: Build vocab on full datasets.
# [2023-02-16 08:46:16,188 INFO] * Transform statistics for corpus_1(50.00%):
# 			* FilterTooLongStats(filtered=44)
#
# [2023-02-16 08:46:16,827 INFO] * Transform statistics for corpus_1(50.00%):
# 			* FilterTooLongStats(filtered=42)
#
# [2023-02-16 08:46:16,934 INFO] Counters src:48304
# [2023-02-16 08:46:16,934 INFO] Counters tgt:49993

# %% [markdown]
# Have a look at the *run* sub-folder in your Google Drive folder to check whether a *source.vocab* and a *target.vocab* file have been created. It might take a moment to load.
#
# **Checking the Vocabulary Files**
#
# It is always good practice to check your files in between steps to make sure that everything has worked well. Run the cell below to print the first and last five vocabulary entries of the source and target vocabulary files.

# %%
print("First 5 vocabulary entries:")
# !head -n 5 'run/source.vocab' && echo "----" && head -n 5 'run/target.vocab'
print()
print("Last 5 vocabulary entries:")
# !tail -n 5 'run/source.vocab' && echo "-----" && tail -n 5 'run/target.vocab'
# Out:
# First 5 vocabulary entries:
# ,	257646
# .	207678
# ▁the	166028
# ▁to	106896
# '	101288
# ----
# ,	300765
# .	222474
# ▁die	90405
# ▁und	83564
# ▁der	59208
#
# Last 5 vocabulary entries:
# inventor	1
# ▁Paperfuge	1
# ▁igloo	1
# Genes	1
# injured	1
# -----
# zuschlafen	1
# ▁auszuradieren	1
# ▁kultige	1
# ▁Poliomyelitis	1
# Deshalb	1

# %% [markdown]
# # Training
#
# Congratulations on creating the configuration and the vocabulary files! You are now ready to train your own NMT model from scratch! 🎉
#
# Once again, make sure that the configuration file is saved in your original folder under **`config.yaml`**, and the vocabulary files are saved in the *run* folder as `source.vocab` and `target.vocab`.
#
# You can now simply run the cell below and your models will start loading! This step will take around **ONE HOUR** (which means it's coffee time for you). During this time, your computer must **remain on**, it cannot go into standby mode! This is very important. If the computer goes into standby mode or if you close this window, the training **will stop** and you would need to start again.
#
# **NOTE: This step is only done once! If you have made a mistake, delete the created models folder (and model files in that folder) and the train-log file (if already created) and run the cell again.**
#
# **Alternatively, save the previously created files and models in a separate folder (named differently) and run through the process again.**

# %% [markdown]
# ## Training Explained

# %% [markdown]
# The model training is explained in more detail in the tutorial video. Here is just a brief summary of interesting aspects to consider:
# * `Step 100/4000` – This indicates the first 100 training steps of a total of 4000. Each subsequent training step will be printed. The model training ends after it has completed `Step 4000/4000`, after the final validation has been done and the final checkpoint (*model.fren_step_4000.pt*) has been saved.
# * `acc` – This refers to the **accuracy** of the NMT model (the higher the accuracy, the higher the model quality). Accuracy starts at a very low value and increases as the training progresses. The idea is to get as high an accuracy value as possible. For longer training times, the accuracy might stall, at which point there is no further improvement (risk of [overfitting](https://machinelearningmastery.com/overfitting-and-underfitting-with-machine-learning-algorithms/)) and the training should be stopped.
# * `xent` – This refers to the **cross entropy** (which indicates the gap between the actual and the desired state of the model i.e., the lower the cross entropy, the higher the model quality). Cross entropy decreases as the training progresses. Ideally, we want this value to be as close to zero as possible. In our present NMT trainings scenario, the value will likely remain at a value of 2.something.

# %% [markdown]
# ## Training the NMT Model
#
# Run the code cell below to start training your NMT model.

# %%
# Train the NMT model
# !onmt_train -config config.yaml
# Out:
# [2023-02-16 08:52:00,556 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2023-02-16 08:52:00,557 INFO] Parsed 2 corpora from -data.
# [2023-02-16 08:52:00,558 INFO] Get special vocabs from Transforms: {'src': [], 'tgt': []}.
# [2023-02-16 08:52:00,834 INFO] Building model...
# [2023-02-16 08:52:06,480 INFO] NMTModel(
#   (encoder): TransformerEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(48312, 512, padding_idx=1)
#         )
#         (pe): PositionalEncoding()
#       )
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=False)
#           (linear_values): Linear(in_features=512, out_features=512, bias=False)
#           (linear_query): Linear(in_features=512, out_features=512, bias=False)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=False)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (1): TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=False)
#           (linear_values): Linear(in_features=512, out_features=512, bias=False)
#           (linear_query): Linear(in_features=512, out_features=512, bias=False)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=False)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (2): TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=False)
#           (linear_values): Linear(in_features=512, out_features=512, bias=False)
#           (linear_query): Linear(in_features=512, out_features=512, bias=False)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=False)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (3): TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=False)
#           (linear_values): Linear(in_features=512, out_features=512, bias=False)
#           (linear_query): Linear(in_features=512, out_features=512, bias=False)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=False)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (4): TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=False)
#           (linear_values): Linear(in_features=512, out_features=512, bias=False)
#           (linear_query): Linear(in_features=512, out_features=512, bias=False)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=False)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (5): TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=False)
#           (linear_values): Linear(in_features=512, out_features=512, bias=False)
#           (linear_query): Linear(in_features=512, out_features=512, bias=False)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=False)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#   )
#   (decoder): TransformerDecoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(50000, 512, padding_idx=1)
#         )
#         (pe): PositionalEncoding()
#       )
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#     (transformer_layers): ModuleList(
#       (0): TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=False)
#           (linear_values): Linear(in_features=512, out_features=512, bias=False)
#           (linear_query): Linear(in_features=512, out_features=512, bias=False)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=False)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (drop): Dropout(p=0.1, inplace=False)
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=False)
#           (linear_values): Linear(in_features=512, out_features=512, bias=False)
#           (linear_query): Linear(in_features=512, out_features=512, bias=False)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=False)
#         )
#         (layer_norm_2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       )
#       (1): TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=False)
#           (linear_values): Linear(in_features=512, out_features=512, bias=False)
#           (linear_query): Linear(in_features=512, out_features=512, bias=False)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=False)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (drop): Dropout(p=0.1, inplace=False)
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=False)
#           (linear_values): Linear(in_features=512, out_features=512, bias=False)
#           (linear_query): Linear(in_features=512, out_features=512, bias=False)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=False)
#         )
#         (layer_norm_2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       )
#       (2): TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=False)
#           (linear_values): Linear(in_features=512, out_features=512, bias=False)
#           (linear_query): Linear(in_features=512, out_features=512, bias=False)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=False)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (drop): Dropout(p=0.1, inplace=False)
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=False)
#           (linear_values): Linear(in_features=512, out_features=512, bias=False)
#           (linear_query): Linear(in_features=512, out_features=512, bias=False)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=False)
#         )
#         (layer_norm_2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       )
#       (3): TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=False)
#           (linear_values): Linear(in_features=512, out_features=512, bias=False)
#           (linear_query): Linear(in_features=512, out_features=512, bias=False)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=False)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (drop): Dropout(p=0.1, inplace=False)
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=False)
#           (linear_values): Linear(in_features=512, out_features=512, bias=False)
#           (linear_query): Linear(in_features=512, out_features=512, bias=False)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=False)
#         )
#         (layer_norm_2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       )
#       (4): TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=False)
#           (linear_values): Linear(in_features=512, out_features=512, bias=False)
#           (linear_query): Linear(in_features=512, out_features=512, bias=False)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=False)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (drop): Dropout(p=0.1, inplace=False)
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=False)
#           (linear_values): Linear(in_features=512, out_features=512, bias=False)
#           (linear_query): Linear(in_features=512, out_features=512, bias=False)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=False)
#         )
#         (layer_norm_2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       )
#       (5): TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=False)
#           (linear_values): Linear(in_features=512, out_features=512, bias=False)
#           (linear_query): Linear(in_features=512, out_features=512, bias=False)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=False)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (drop): Dropout(p=0.1, inplace=False)
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=False)
#           (linear_values): Linear(in_features=512, out_features=512, bias=False)
#           (linear_query): Linear(in_features=512, out_features=512, bias=False)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=False)
#         )
#         (layer_norm_2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       )
#     )
#   )
#   (generator): Linear(in_features=512, out_features=50000, bias=True)
# )
# [2023-02-16 08:52:06,489 INFO] encoder: 43638784
# [2023-02-16 08:52:06,489 INFO] decoder: 76450640
# [2023-02-16 08:52:06,490 INFO] * number of parameters: 120089424
# [2023-02-16 08:52:06,490 INFO]  * src vocab size = 48312
# [2023-02-16 08:52:06,490 INFO]  * tgt vocab size = 50000
# [2023-02-16 08:52:06,495 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 1
# [2023-02-16 08:52:06,495 INFO] Starting training on GPU: [0]
# [2023-02-16 08:52:06,495 INFO] Start training loop and validate every 1000 steps...
# [2023-02-16 08:52:06,496 INFO] Scoring with: TransformPipe(FilterTooLongTransform(src_seq_length=150, tgt_seq_length=192))
# [2023-02-16 08:52:11,633 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 2
# [2023-02-16 08:53:47,412 INFO] Step 100/ 4000; acc: 6.4; ppl: 13207.7; xent: 9.5; lr: 0.00014; sents:   70439; bsz: 3731/3712/176; 14789/14713 tok/s;    101 sec;
# [2023-02-16 08:55:12,633 INFO] Step 200/ 4000; acc: 12.8; ppl: 1442.5; xent: 7.3; lr: 0.00028; sents:   64514; bsz: 3751/3720/161; 17606/17461 tok/s;    186 sec;
# [2023-02-16 08:56:38,998 INFO] Step 300/ 4000; acc: 16.8; ppl: 776.5; xent: 6.7; lr: 0.00042; sents:   72161; bsz: 3730/3708/180; 17276/17175 tok/s;    273 sec;
# [2023-02-16 08:57:53,082 INFO] * Transform statistics for corpus_1(100.00%):
# 			* FilterTooLongStats(filtered=104)
#
# [2023-02-16 08:57:53,082 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 3
# [2023-02-16 08:58:30,323 INFO] Step 400/ 4000; acc: 19.7; ppl: 521.0; xent: 6.3; lr: 0.00056; sents:   69852; bsz: 3736/3711/175; 13425/13333 tok/s;    384 sec;
# [2023-02-16 08:59:57,371 INFO] Step 500/ 4000; acc: 25.1; ppl: 347.6; xent: 5.9; lr: 0.00070; sents:   69188; bsz: 3733/3706/173; 17154/17031 tok/s;    471 sec;
# [2023-02-16 09:01:24,758 INFO] Step 600/ 4000; acc: 31.1; ppl: 227.2; xent: 5.4; lr: 0.00084; sents:   71252; bsz: 3735/3711/178; 17098/16988 tok/s;    558 sec;
# [2023-02-16 09:02:52,021 INFO] Step 700/ 4000; acc: 35.5; ppl: 161.5; xent: 5.1; lr: 0.00098; sents:   67504; bsz: 3738/3711/169; 17137/17013 tok/s;    646 sec;
# [2023-02-16 09:03:43,377 INFO] * Transform statistics for corpus_1(100.00%):
# 			* FilterTooLongStats(filtered=100)
#
# [2023-02-16 09:03:43,377 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 4
# [2023-02-16 09:04:40,196 INFO] Step 800/ 4000; acc: 40.5; ppl: 109.1; xent: 4.7; lr: 0.00112; sents:   69615; bsz: 3735/3714/174; 13813/13732 tok/s;    754 sec;
# [2023-02-16 09:06:07,290 INFO] Step 900/ 4000; acc: 43.9; ppl:  83.7; xent: 4.4; lr: 0.00126; sents:   69228; bsz: 3742/3711/173; 17185/17044 tok/s;    841 sec;
# [2023-02-16 09:07:34,719 INFO] Step 1000/ 4000; acc: 45.5; ppl:  73.8; xent: 4.3; lr: 0.00140; sents:   66892; bsz: 3747/3716/167; 17141/16999 tok/s;    928 sec;
# [2023-02-16 09:08:25,554 INFO] valid stats calculation and sentences rebuilding
#                            took: 50.83389186859131 s.
# [2023-02-16 09:08:25,556 INFO] Train perplexity: 382.098
# [2023-02-16 09:08:25,556 INFO] Train accuracy: 27.7375
# [2023-02-16 09:08:25,556 INFO] Sentences processed: 690645
# [2023-02-16 09:08:25,556 INFO] Average bsz: 3738/3712/173
# [2023-02-16 09:08:25,556 INFO] Validation perplexity: 72.6565
# [2023-02-16 09:08:25,556 INFO] Validation accuracy: 46.8293
# [2023-02-16 09:08:25,557 INFO] Model is improving ppl: inf --> 72.6565.
# [2023-02-16 09:08:25,557 INFO] Model is improving acc: -inf --> 46.8293.
# [2023-02-16 09:08:25,594 INFO] Saving checkpoint models/model.fren_step_1000.pt
# [2023-02-16 09:09:58,222 INFO] Step 1100/ 4000; acc: 47.7; ppl:  63.2; xent: 4.1; lr: 0.00133; sents:   71051; bsz: 3727/3709/178; 10388/10337 tok/s;   1072 sec;
# [2023-02-16 09:10:29,191 INFO] * Transform statistics for corpus_1(100.00%):
# 			* FilterTooLongStats(filtered=109)
#
# [2023-02-16 09:10:29,191 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 5
# [2023-02-16 09:11:49,885 INFO] Step 1200/ 4000; acc: 50.8; ppl:  48.1; xent: 3.9; lr: 0.00128; sents:   71706; bsz: 3727/3705/179; 13351/13271 tok/s;   1183 sec;
# [2023-02-16 09:13:16,930 INFO] Step 1300/ 4000; acc: 52.7; ppl:  42.0; xent: 3.7; lr: 0.00123; sents:   69495; bsz: 3734/3708/174; 17157/17040 tok/s;   1270 sec;
# [2023-02-16 09:14:43,965 INFO] Step 1400/ 4000; acc: 53.5; ppl:  39.9; xent: 3.7; lr: 0.00118; sents:   68609; bsz: 3739/3713/172; 17186/17066 tok/s;   1357 sec;
# [2023-02-16 09:16:11,271 INFO] Step 1500/ 4000; acc: 54.2; ppl:  37.9; xent: 3.6; lr: 0.00114; sents:   68777; bsz: 3740/3716/172; 17137/17025 tok/s;   1445 sec;
# [2023-02-16 09:16:18,814 INFO] * Transform statistics for corpus_1(100.00%):
# 			* FilterTooLongStats(filtered=102)
#
# [2023-02-16 09:16:18,814 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 6
# [2023-02-16 09:16:27,417 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 7
# [2023-02-16 09:18:03,408 INFO] Step 1600/ 4000; acc: 58.0; ppl:  28.6; xent: 3.4; lr: 0.00110; sents:   69881; bsz: 3738/3712/175; 13332/13242 tok/s;   1557 sec;
# [2023-02-16 09:19:30,735 INFO] Step 1700/ 4000; acc: 58.1; ppl:  28.6; xent: 3.4; lr: 0.00107; sents:   69243; bsz: 3735/3710/173; 17107/16994 tok/s;   1644 sec;
# [2023-02-16 09:20:57,991 INFO] Step 1800/ 4000; acc: 58.5; ppl:  27.9; xent: 3.3; lr: 0.00104; sents:   68627; bsz: 3737/3715/172; 17134/17032 tok/s;   1731 sec;
# [2023-02-16 09:22:17,957 INFO] * Transform statistics for corpus_1(100.00%):
# 			* FilterTooLongStats(filtered=105)
#
# [2023-02-16 09:22:17,957 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 8
# [2023-02-16 09:22:47,782 INFO] Step 1900/ 4000; acc: 59.6; ppl:  26.3; xent: 3.3; lr: 0.00101; sents:   70932; bsz: 3735/3708/177; 13609/13509 tok/s;   1841 sec;
# [2023-02-16 09:24:14,769 INFO] Step 2000/ 4000; acc: 62.8; ppl:  21.4; xent: 3.1; lr: 0.00099; sents:   67918; bsz: 3744/3715/170; 17216/17081 tok/s;   1928 sec;
# [2023-02-16 09:24:15,290 INFO] * Transform statistics for valid(100.00%):
# 			* FilterTooLongStats(filtered=9)
#
# [2023-02-16 09:25:03,411 INFO] valid stats calculation and sentences rebuilding
#                            took: 48.63998794555664 s.
# [2023-02-16 09:25:03,413 INFO] Train perplexity: 115.043
# [2023-02-16 09:25:03,413 INFO] Train accuracy: 41.6649
# [2023-02-16 09:25:03,413 INFO] Sentences processed: 1.38688e+06
# [2023-02-16 09:25:03,413 INFO] Average bsz: 3737/3712/173
# [2023-02-16 09:25:03,413 INFO] Validation perplexity: 40.3044
# [2023-02-16 09:25:03,413 INFO] Validation accuracy: 55.5951
# [2023-02-16 09:25:03,413 INFO] Model is improving ppl: 72.6565 --> 40.3044.
# [2023-02-16 09:25:03,413 INFO] Model is improving acc: 46.8293 --> 55.5951.
# [2023-02-16 09:25:03,444 INFO] Saving checkpoint models/model.fren_step_2000.pt
# [2023-02-16 09:26:36,205 INFO] Step 2100/ 4000; acc: 62.2; ppl:  22.0; xent: 3.1; lr: 0.00096; sents:   68220; bsz: 3735/3714/171; 10564/10504 tok/s;   2070 sec;
# [2023-02-16 09:28:03,515 INFO] Step 2200/ 4000; acc: 62.6; ppl:  21.7; xent: 3.1; lr: 0.00094; sents:   70276; bsz: 3732/3711/176; 17096/17000 tok/s;   2157 sec;
# [2023-02-16 09:29:02,737 INFO] * Transform statistics for corpus_1(100.00%):
# 			* FilterTooLongStats(filtered=102)
#
# [2023-02-16 09:29:02,737 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9
# [2023-02-16 09:29:57,786 INFO] Step 2300/ 4000; acc: 64.2; ppl:  19.9; xent: 3.0; lr: 0.00092; sents:   70087; bsz: 3738/3713/175; 13084/12996 tok/s;   2271 sec;
# [2023-02-16 09:31:24,934 INFO] Step 2400/ 4000; acc: 66.3; ppl:  17.6; xent: 2.9; lr: 0.00090; sents:   68279; bsz: 3741/3714/171; 17172/17046 tok/s;   2358 sec;
# [2023-02-16 09:32:52,477 INFO] Step 2500/ 4000; acc: 65.8; ppl:  18.1; xent: 2.9; lr: 0.00088; sents:   71415; bsz: 3728/3706/179; 17033/16936 tok/s;   2446 sec;
# [2023-02-16 09:34:19,662 INFO] Step 2600/ 4000; acc: 65.8; ppl:  18.0; xent: 2.9; lr: 0.00087; sents:   70737; bsz: 3730/3707/177; 17113/17007 tok/s;   2533 sec;
# [2023-02-16 09:34:55,488 INFO] * Transform statistics for corpus_1(100.00%):
# 			* FilterTooLongStats(filtered=101)
#
# [2023-02-16 09:34:55,488 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 10
# [2023-02-16 09:36:10,576 INFO] Step 2700/ 4000; acc: 68.3; ppl:  16.0; xent: 2.8; lr: 0.00085; sents:   68922; bsz: 3741/3712/172; 13492/13386 tok/s;   2644 sec;
# [2023-02-16 09:37:37,882 INFO] Step 2800/ 4000; acc: 69.4; ppl:  15.1; xent: 2.7; lr: 0.00084; sents:   69823; bsz: 3735/3715/175; 17114/17020 tok/s;   2731 sec;
# [2023-02-16 09:39:05,231 INFO] Step 2900/ 4000; acc: 68.5; ppl:  15.7; xent: 2.8; lr: 0.00082; sents:   66928; bsz: 3745/3712/167; 17151/17000 tok/s;   2819 sec;
# [2023-02-16 09:40:32,662 INFO] Step 3000/ 4000; acc: 68.6; ppl:  15.7; xent: 2.8; lr: 0.00081; sents:   69891; bsz: 3731/3706/175; 17068/16957 tok/s;   2906 sec;
# [2023-02-16 09:40:33,184 INFO] * Transform statistics for valid(100.00%):
# 			* FilterTooLongStats(filtered=9)
#
# [2023-02-16 09:41:19,548 INFO] valid stats calculation and sentences rebuilding
#                            took: 46.88481616973877 s.
# [2023-02-16 09:41:19,550 INFO] Train perplexity: 61.7953
# [2023-02-16 09:41:19,550 INFO] Train accuracy: 49.836
# [2023-02-16 09:41:19,550 INFO] Sentences processed: 2.08146e+06
# [2023-02-16 09:41:19,550 INFO] Average bsz: 3736/3711/173
# [2023-02-16 09:41:19,550 INFO] Validation perplexity: 38.4245
# [2023-02-16 09:41:19,550 INFO] Validation accuracy: 56.782
# [2023-02-16 09:41:19,550 INFO] Model is improving ppl: 40.3044 --> 38.4245.
# [2023-02-16 09:41:19,550 INFO] Model is improving acc: 55.5951 --> 56.782.
# [2023-02-16 09:41:19,582 INFO] Saving checkpoint models/model.fren_step_3000.pt
# [2023-02-16 09:41:42,317 INFO] * Transform statistics for corpus_1(100.00%):
# 			* FilterTooLongStats(filtered=110)
#
# [2023-02-16 09:41:42,318 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 11
# [2023-02-16 09:43:22,847 INFO] Step 3100/ 4000; acc: 71.7; ppl:  13.6; xent: 2.6; lr: 0.00079; sents:   66667; bsz: 3740/3714/167; 8791/8729 tok/s;   3076 sec;
# [2023-02-16 09:44:50,218 INFO] Step 3200/ 4000; acc: 71.8; ppl:  13.4; xent: 2.6; lr: 0.00078; sents:   71044; bsz: 3733/3710/178; 17091/16987 tok/s;   3164 sec;
# [2023-02-16 09:46:17,502 INFO] Step 3300/ 4000; acc: 71.3; ppl:  13.8; xent: 2.6; lr: 0.00077; sents:   69826; bsz: 3732/3709/175; 17105/16997 tok/s;   3251 sec;
# [2023-02-16 09:47:40,138 INFO] * Transform statistics for corpus_1(100.00%):
# 			* FilterTooLongStats(filtered=103)
#
# [2023-02-16 09:47:40,138 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 12
# [2023-02-16 09:47:46,344 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 13
# [2023-02-16 09:48:09,031 INFO] Step 3400/ 4000; acc: 71.1; ppl:  13.8; xent: 2.6; lr: 0.00076; sents:   69602; bsz: 3740/3715/174; 13414/13323 tok/s;   3363 sec;
# [2023-02-16 09:49:36,705 INFO] Step 3500/ 4000; acc: 74.4; ppl:  12.0; xent: 2.5; lr: 0.00075; sents:   68911; bsz: 3735/3711/172; 17041/16933 tok/s;   3450 sec;
# [2023-02-16 09:51:03,905 INFO] Step 3600/ 4000; acc: 74.0; ppl:  12.2; xent: 2.5; lr: 0.00074; sents:   68299; bsz: 3743/3716/171; 17169/17044 tok/s;   3537 sec;
# [2023-02-16 09:52:31,204 INFO] Step 3700/ 4000; acc: 73.8; ppl:  12.3; xent: 2.5; lr: 0.00073; sents:   72809; bsz: 3730/3708/182; 17091/16991 tok/s;   3625 sec;
# [2023-02-16 09:53:41,807 INFO] * Transform statistics for corpus_1(100.00%):
# 			* FilterTooLongStats(filtered=104)
#
# [2023-02-16 09:53:41,807 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 14
# [2023-02-16 09:54:26,340 INFO] Step 3800/ 4000; acc: 73.9; ppl:  12.2; xent: 2.5; lr: 0.00072; sents:   67059; bsz: 3735/3707/168; 12977/12880 tok/s;   3740 sec;
# [2023-02-16 09:55:53,862 INFO] Step 3900/ 4000; acc: 76.4; ppl:  11.0; xent: 2.4; lr: 0.00071; sents:   70753; bsz: 3731/3707/177; 17053/16941 tok/s;   3827 sec;
# [2023-02-16 09:57:21,156 INFO] Step 4000/ 4000; acc: 75.8; ppl:  11.3; xent: 2.4; lr: 0.00070; sents:   67275; bsz: 3734/3708/168; 17111/16993 tok/s;   3915 sec;
# [2023-02-16 09:57:21,716 INFO] * Transform statistics for valid(100.00%):
# 			* FilterTooLongStats(filtered=9)
#
# [2023-02-16 09:58:08,029 INFO] valid stats calculation and sentences rebuilding
#                            took: 46.871803283691406 s.
# [2023-02-16 09:58:08,031 INFO] Train perplexity: 41.4638
# [2023-02-16 09:58:08,031 INFO] Train accuracy: 55.73
# [2023-02-16 09:58:08,031 INFO] Sentences processed: 2.77371e+06
# [2023-02-16 09:58:08,031 INFO] Average bsz: 3736/3711/173
# [2023-02-16 09:58:08,031 INFO] Validation perplexity: 42.0468
# [2023-02-16 09:58:08,031 INFO] Validation accuracy: 56.6122
# [2023-02-16 09:58:08,031 INFO] Decreasing patience: 9/10
# [2023-02-16 09:58:08,062 INFO] Saving checkpoint models/model.fren_step_4000.pt

# %% [markdown]
# Congratulations – you have trained your own NMT model!

# %% [markdown]
# # Translation

# %% [markdown]
# Now it's time to put your model to test by translating your first test file. For this step, the code cell below refers to your *latest model*, which should be saved in the *models* folder in your original Drive folder as **model.fren_step_4000.pt**. The cell also refers to your test dataset, which should be saved in your original Drive folder as `TED2020.de-en.en-filtered.en.subword.test`.
#
# In the cell below, we define the `-output` (the translation produced by the model) to be named **translation**. This creates a file in your folder simply called **translation**.
#
# You can now simply run the cell below. Your NMT model will then produce a subworded translation of your test dataset. Translating this dataset will take some time. The translation output will be printed during the process.

# %% [markdown]
# ## Translation Explained

# %% [markdown]
# Let's have a closer look at the translation options available in the code cell below:
# * `-model` – Refers to the last model checkpoint name. You can try testing the quality of multiple checkpoints.
# * `-src` – Refers to the source file: the subworded test dataset.
# * `-output` – Refers to the new translation output file; this can be named as required (we call it *translation*).
# * `-gpu` – Is set to 0, meaning that you actually use one GPU.
# * `-min_length` – [optional] To avoid empty translations, we set this value to 2.
# * `-verbose` – [optional] Prints the translations during the process. You could delete `-verbose` if you don't want to see the translation below.
#
# You can refer to the [OpenNMT-py translation options](https://opennmt.net/OpenNMT-py/options/translate.html) for more details.

# %% [markdown]
# ## Translating

# %%
# Translate the subworded source file of the test dataset
# !onmt_translate -model models/model.fren_step_4000.pt -src TED2020.de-en.en-filtered.en.subword.test -output translation -gpu 0 --min_length 2 --verbose
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
# SENT 34001: ['▁So', '▁I', '▁wasn', "'", 't', '▁going', '▁to', '▁tell', '▁her', '▁about', '▁this', '▁idea', ',', '▁but', '▁the', '▁next', '▁day', '▁I', '▁couldn', "'", 't', '▁control', '▁myself', ',', '▁I', '▁told', '▁her', '.']
# PRED 34001: ▁Ich ▁würde ▁ihr ▁also ▁nicht ▁von ▁dieser ▁Idee ▁erzählen , ▁aber ▁am ▁nächsten ▁Tag ▁konnte ▁ich ▁mich ▁nicht ▁selbst ▁kontrollieren , ▁ich ▁erzählte ▁ihr .
# PRED SCORE: -0.3298
#
# [2023-02-16 10:22:36,154 INFO]
# SENT 34002: ['▁And', '▁you', '▁already', '▁heard', '▁that', '▁less', '▁than', '▁one', '▁percent', '▁of', '▁the', '▁ocean', "'", 's', '▁protected', '.']
# PRED 34002: ▁Und ▁Sie ▁haben ▁schon ▁davon ▁gehört , ▁dass ▁weniger ▁als ▁ein ▁Prozent ▁des ▁Meeres ▁geschützt ▁sind .
# PRED SCORE: -0.4225
#
# [2023-02-16 10:22:36,155 INFO]
# SENT 34003: ['▁Also', ',', '▁more', '▁so', '▁than', '▁our', '▁credit', '▁history', ',', '▁we', '▁can', '▁actually', '▁shape', '▁our', '▁reputation', '.']
# PRED 34003: ▁Außerdem ▁können ▁wir , ▁mehr ▁als ▁unsere ▁Bonität , ▁unseren ▁Ruf ▁gestalten .
# PRED SCORE: -0.5611
#
# [2023-02-16 10:22:36,155 INFO]
# SENT 34004: ['▁We', '▁have', '▁found', '▁a', '▁lot', '▁of', '▁evidence', '▁that', '▁dinosaurs', '▁changed', '▁from', '▁when', '▁they', '▁were', '▁juveniles', '▁to', '▁when', '▁they', '▁were', '▁adults', '.']
# PRED 34004: ▁Wir ▁haben ▁viele ▁Beweise ▁gefunden , ▁dass ▁Dinosaurier ▁sich ▁geändert ▁haben , ▁als ▁sie ▁Kleinkinder ▁waren , ▁wenn ▁sie ▁erwachsen ▁sind .
# PRED SCORE: -0.4202
#
# [2023-02-16 10:22:36,155 INFO]
# SENT 34005: ['▁He', '▁found', '▁a', '▁duct', '▁in', '▁animal', '▁skulls', '▁that', '▁send', 's', '▁saliva', '▁to', '▁the', '▁mouth', '.']
# PRED 34005: ▁Er ▁fand ▁einen ▁Schwimm körper , ▁der ▁den ▁Mund ▁zum ▁Mund ▁sendet .
# PRED SCORE: -0.4387
#
# [2023-02-16 10:22:36,155 INFO]
# SENT 34006: ['▁You', '▁have', '▁a', '▁little', '▁more', '▁of', '▁a', '▁conversation', '▁with', '▁your', '▁physician', '▁and', '▁the', '▁physician', '▁is', '▁a', '▁little', '▁worried', '▁because', '▁you', "'", 've', '▁been', '▁blue', ',', '▁haven', "'", 't', '▁felt', '▁like', '▁yourself', ',', '▁you', '▁haven', "'", 't', '▁been', '▁able', '▁to', '▁enjoy', '▁things', '▁in', '▁life', '▁quite', '▁as', '▁much', '▁as', '▁you', '▁usually', '▁do', '.']
# PRED 34006: ▁Sie ▁haben ▁ein ▁bisschen ▁mehr ▁Gespräche ▁mit ▁Ihrem ▁Arzt ▁und ▁der ▁Arzt ▁ist ▁etwas ▁besorgt , ▁denn ▁Sie ▁waren ▁blau , ▁Sie ▁haben ▁sich ▁nicht ▁so ▁gefühlt , ▁dass ▁man ▁Dinge ▁im ▁Leben ▁nicht ▁so ▁gut ▁genießen ▁konnte , ▁wie ▁man ▁es ▁normalerweise ▁macht .
# PRED SCORE: -0.5704
#
# [2023-02-16 10:22:36,156 INFO]
# SENT 34007: ['▁Detroiters', '▁are', '▁hungry', '▁for', '▁culturally', '▁appropriate', ',', '▁fresh', ',', '▁delicious', '▁food', '.']
# PRED 34007: ▁Die ▁Detroiter ▁töten ▁für ▁die ▁Kultur , ▁frische ▁und ▁lecker e ▁Nahrung .
# PRED SCORE: -0.5379
#
# [2023-02-16 10:22:36,156 INFO]
# SENT 34008: ['▁That', "'", 's', '▁why', '▁I', "'", 'm', '▁sitting', '▁here', '.']
# PRED 34008: ▁Deshalb ▁sitze ▁ich ▁hier .
# PRED SCORE: -0.3371
#
# [2023-02-16 10:22:36,156 INFO]
# SENT 34009: ['▁It', '▁was', '▁part', '▁of', '▁the', '▁business', '▁of', '▁life', '▁in', '▁general', '.']
# PRED 34009: ▁Es ▁war ▁ein ▁Teil ▁des ▁Lebens ▁im ▁Allgemeinen .
# PRED SCORE: -0.3542
#
# [2023-02-16 10:22:36,157 INFO]
# SENT 34010: ['▁Does', '▁all', '▁of', '▁this', '▁make', '▁you', '▁feel', '▁small', '?']
# PRED 34010: ▁Ist ▁das ▁alles , ▁was ▁einen ▁klein ▁fühlt ?
# PRED SCORE: -0.5704
#
# [2023-02-16 10:22:36,157 INFO]
# SENT 34011: ['▁So', '▁with', '▁paper', ',', '▁copper', '▁tape', ',', '▁lightbulb', '▁and', '▁a', '▁battery', ',', '▁people', '▁can', '▁complete', '▁this', '▁project', '▁for', '▁under', '▁a', '▁dollar', '.']
# PRED 34011: ▁Mit ▁Papier , ▁Kupfer kle n ium , ▁und ▁eine ▁Batterie ▁können ▁die ▁Leute ▁dieses ▁Projekt ▁unter ▁einem ▁Dollar ▁komplett ▁lösen .
# PRED SCORE: -0.5882
#
# [2023-02-16 10:22:36,157 INFO]
# SENT 34012: ['▁The', '▁education', '▁process', '▁begins', '▁even', '▁before', '▁the', '▁child', '▁is', '▁born', ',', '▁and', '▁if', '▁you', '▁don', "'", 't', '▁do', '▁that', ',', '▁you', "'", 're', '▁going', '▁to', '▁have', '▁difficulty', '.']
# PRED 34012: ▁Der ▁Bildung sprozess ▁beginnt ▁noch ▁bevor ▁das ▁Kind ▁geboren ▁wird . ▁Und ▁wenn ▁Sie ▁das ▁nicht ▁tun , ▁werden ▁Sie ▁Schwierigkeiten ▁haben .
# PRED SCORE: -0.3458
#
# [2023-02-16 10:22:36,158 INFO]
# SENT 34013: ['<unk>', 'ory', '▁budgeting', '▁has', '▁long', '▁been', '▁practiced', '▁in', '▁Porto', '▁A', 'leg', 're', ',', '▁Brazil', '.']
# PRED 34013: ▁Eskalation ▁ist ▁schon ▁lange ▁in ▁Porto , ▁Brasilien ▁oder ▁Brasilien ▁praktiziert ▁worden .
# PRED SCORE: -0.6833
#
# [2023-02-16 10:22:36,158 INFO]
# SENT 34014: ['▁On', '▁the', '▁flip', '▁side', '▁of', '▁that', ',', '▁I', '▁struggled', '▁with', '▁very', '▁severe', '▁performance', '▁anxiety', '.']
# PRED 34014: ▁Auf ▁der ▁anderen ▁Seite ▁davon ▁hatte ▁ich ▁Probleme ▁mit ▁sehr ▁schwerer en ▁Vorstellung .
# PRED SCORE: -0.6336
#
# [2023-02-16 10:22:36,158 INFO]
# SENT 34015: ['▁And', '▁now', ',', '▁with', '▁the', '▁experience', '▁economy', ',', '▁it', "'", 's', '▁about', '▁rendering', '▁authenticity', '.']
# PRED 34015: ▁Und ▁nun , ▁mit ▁der ▁Erfahrung ▁der ▁Wirtschaft , ▁geht ▁es ▁um ▁die ▁Bestimmung ▁der ▁Authentizität .
# PRED SCORE: -0.3601
#
# [2023-02-16 10:22:36,158 INFO]
# SENT 34016: ['▁This', '▁unwitting', '▁ape', '▁has', '▁stumble', 'd', '▁on', '▁a', '▁process', '▁that', '▁humans', '▁will', '▁eventually', '▁harness', '▁to', '▁create', '▁beer', ',', '▁wine', ',', '▁and', '▁other', '▁alcoholic', '▁drinks', '.']
# PRED 34016: ▁ Dieser ▁Affe ▁ist ▁auf ▁einem ▁Prozess ▁angelangt , ▁den ▁Menschen ▁dann ▁nutzen ▁werden , ▁um ▁Bier , ▁Wein ▁zu ▁schaffen , ▁und ▁ein ▁anderer ▁Getränk .
# PRED SCORE: -0.5441
#
# [2023-02-16 10:22:36,159 INFO]
# SENT 34017: ['▁You', "'", 're', '▁making', '▁', '1', '0', '0', '▁percent', '▁contrast', '▁between', '▁microcredit', '▁and', '▁regular', '▁investment', '▁and', '▁growing', '▁regular', '▁investment', '.']
# PRED 34017: ▁Sie ▁machen ▁ 1 0 0 ▁Prozent ▁des ▁Unterschied s ▁zwischen ▁Mikrokredite ▁und ▁normalen ▁Investitionen .
# PRED SCORE: -0.4845
#
# [2023-02-16 10:22:36,159 INFO]
# SENT 34018: ['▁CA', ':', '▁Rick', ',', '▁when', '▁Ed', '▁Snowden', '▁ended', '▁his', '▁talk', ',', '▁I', '▁offered', '▁him', '▁the', '▁chance', '▁to', '▁share', '▁an', '▁idea', '▁worth', '▁spreading', '.']
# PRED 34018: ▁CA : ▁Rick , ▁als ▁Ed ▁Snowden ▁seinen ▁Vortrag ▁beendete , ▁bot ▁ich ▁ihm ▁die ▁Möglichkeit , ▁eine ▁Idee ▁zu ▁verbreiten .
# PRED SCORE: -0.2497
#
# [2023-02-16 10:22:36,159 INFO]
# SENT 34019: ['▁Not', '▁normally', '▁--', '▁(', 'Applause', ')', '▁Thank', '▁you', '.']
# PRED 34019: ▁Nicht ▁normalerweise ▁-- ▁( Applaus ) ▁Danke .
# PRED SCORE: -0.4241
#
# [2023-02-16 10:22:36,160 INFO]
# SENT 34020: ['▁I', 's', '▁love', '▁a', '▁disguise', '▁for', '▁our', '▁sexual', '▁desire', ',', '▁or', '▁a', '▁trick', '▁of', '▁biology', '▁to', '▁make', '▁us', '▁procreate', '?']
# PRED 34020: ▁Ist ▁es ▁Liebe ▁für ▁unsere ▁sexuelle ▁Begeisterung ▁oder ▁ein ▁Trick ▁in ▁der ▁Biologie , ▁um ▁uns ▁zu ▁erschaffen ?
# PRED SCORE: -0.5660
#
# [2023-02-16 10:22:36,160 INFO]
# SENT 34021: ['▁Now', ',', '▁it', "'", 's', '▁really', '▁convenient', '▁that', '▁spiders', '▁use', '▁their', '▁silk', '▁completely', '▁outside', '▁their', '▁body', '.']
# PRED 34021: ▁Es ▁ist ▁wirklich ▁praktisch , ▁dass ▁Spinnen ▁ihre ▁Seide ▁komplett ▁außerhalb ▁ihres ▁Körpers ▁benützen .
# PRED SCORE: -0.4003
#
# [2023-02-16 10:22:36,160 INFO]
# SENT 34022: ['▁And', '▁my', '▁head', '▁was', '▁swoon', 'ing', '▁over', '▁that', '▁overcooked', '▁piece', '▁of', '▁delicious', '▁fish', '▁I', '▁had', '▁the', '▁night', '▁before', '.']
# PRED 34022: ▁Und ▁mein ▁Kopf ▁wurde ▁über ▁diesen ▁Pier s stück ▁zu ▁einem ▁köstlich en ▁Fisch ▁zurück gefahren , ▁den ▁ich ▁vor ▁der ▁Nacht ▁hatte .
# PRED SCORE: -0.6651
#
# [2023-02-16 10:22:36,160 INFO]
# SENT 34023: ['▁And', '▁it', "'", 's', '▁interesting', '▁that', '▁Fildes', '▁picked', '▁this', '▁topic', '.']
# PRED 34023: ▁Und ▁es ▁ist ▁interessant , ▁dass ▁Fildes ▁dieses ▁Thema ▁ausgewählt ▁hat .
# PRED SCORE: -0.2907
#
# [2023-02-16 10:22:36,161 INFO]
# SENT 34024: ['▁Before', '▁it', "'", 's', '▁all', '▁done', '▁we', '▁are', '▁going', '▁to', '▁alter', '▁ourselves', '▁every', '▁bit', '▁as', '▁much', '▁as', '▁we', '▁have', '▁changed', '▁the', '▁world', '▁around', '▁us', '.']
# PRED 34024: ▁Bevor ▁es ▁fertig ▁ist , ▁werden ▁wir ▁uns ▁jedes ▁Mal ▁so ▁sehr ▁verändern , ▁wie ▁wir ▁die ▁Welt ▁um ▁uns ▁herum ▁verändert ▁haben .
# PRED SCORE: -0.3389
#
# [2023-02-16 10:22:36,161 INFO]
# SENT 34025: ['▁Dr', '.', '▁Rudy', '▁Leib', 'el', '▁of', '▁Columbia', '▁University', '▁has', '▁found', '▁that', '▁people', '▁who', '▁have', '▁lost', '▁', '1', '0', '▁percent', '▁of', '▁their', '▁body', '▁weight', '▁burn', '▁', '2', '5', '0', '▁to', '▁', '4', '0', '0', '▁calories', '▁less', '▁because', '▁their', '▁metabolism', '▁is', '▁suppressed', '.']
# PRED 34025: ▁Dr . ▁Zullinger ▁von ▁der ▁Columbia ▁hat ▁herausgefunden , ▁dass ▁Menschen , ▁die ▁ 1 0 ▁ % ▁ihres ▁Körpergewicht s ▁verloren ▁haben , ▁ 2 5 0 ▁bis ▁ 4 0 0 ▁Kalorien ▁weniger ▁verbrauchen , ▁weil ▁ihr ▁Stoffwechsel ▁unterdrückt .
# PRED SCORE: -0.3274
#
# [2023-02-16 10:22:36,161 INFO]
# SENT 34026: ['▁Certainly', '▁the', '▁percentage', '▁is', '▁low', '▁compar', 'ing', '▁to', '▁the', '▁total', '▁population', '▁if', '▁you', '▁only', '▁live', '▁for', '▁a', '▁hundred', '▁years', '.']
# PRED 34026: ▁Sicherlich ▁ist ▁der ▁Anteil ▁im ▁Vergleich ▁zu ▁der ▁Gesamt bevölkerung , ▁wenn ▁man ▁nur ▁ 1 0 0 ▁Jahre ▁lebt .
# PRED SCORE: -0.4311
#
# [2023-02-16 10:22:36,162 INFO]
# SENT 34027: ['▁The', '▁first', '▁was', '▁to', '▁be', '▁', 'guided', '▁by', '▁principles', '.']
# PRED 34027: ▁Das ▁erste ▁war , ▁von ▁den ▁Grundsätze n ▁geleitet ▁zu ▁werden .
# PRED SCORE: -0.4322
#
# [2023-02-16 10:22:36,162 INFO]
# SENT 34028: ['▁In', '<unk>', '▁settlements', '▁are', '▁incorrectly', '▁named', '▁as', '▁the', '▁problem', '.']
# PRED 34028: ▁Eskalation ▁ist ▁falsch ▁angeordnet , ▁als ▁das ▁Problem .
# PRED SCORE: -0.4324
#
# [2023-02-16 10:22:36,980 INFO]
# SENT 34029: ['▁It', '▁was', '▁nothing', '▁more', '▁than', '▁his', '▁own', '▁words', '▁that', '▁sent', '▁him', '▁to', '▁prison', '▁for', '▁nearly', '▁a', '▁decade', ',', '▁until', '▁a', '▁judge', '▁overturned', '▁his', '▁conviction', '▁just', '▁a', '▁few', '▁months', '▁ago', '.']
# PRED 34029: ▁Es ▁war ▁nichts ▁mehr ▁als ▁seine ▁eigenen ▁Worte , ▁die ▁ihn ▁fast ▁ 1 0 ▁Jahre ▁lang ▁ins ▁Gefängnis ▁brachte , ▁bis ▁ein ▁Richter ▁seine ▁Überzeugung ▁erst ▁vor ▁ein ▁paar ▁Monaten ▁stellte .
# PRED SCORE: -0.3393
#
# [2023-02-16 10:22:36,980 INFO]
# SENT 34030: ['▁Recently', ',', '▁we', '▁used', '▁machine', '▁learning', '▁to', '▁discover', '▁new', '▁antibiotics', '▁that', '▁can', '▁help', '▁us', '▁fight', '▁off', '▁the', '▁bacterial', '▁infections', '▁that', '▁can', '▁occur', '▁along', 'side', '▁SARS', '-', 'Co', 'V', '-', '2', '▁infections', '.']
# PRED 34030: ▁Kürzlich ▁haben ▁wir ▁maschinelle s ▁Lernen ▁verwendet , ▁um ▁neue ▁Antibiotika ▁zu ▁entdecken , ▁die ▁uns ▁helfen ▁können , ▁vor ▁den ▁Bakterien ▁Infektionen ▁zu ▁bekämpfen , ▁die ▁bei ▁CO VID - 1 9 - 2 ▁Infektionen ▁auftreten .
# PRED SCORE: -0.5081
#
# [2023-02-16 10:22:36,980 INFO]
# SENT 34031: ['▁The', '▁Dink', 'a', '▁were', '▁still', '▁in', '▁love', '▁with', '▁their', '▁cattle', ',', '▁but', '▁they', '▁had', '▁turned', '▁in', '▁their', '▁spears', '▁for', '▁Kalashnikov', 's', '.']
# PRED 34031: ▁Die ▁Dinka s ▁waren ▁noch ▁immer ▁verliebt ▁mit ▁ihren ▁Rinder n , ▁aber ▁sie ▁hatten ▁ihre ▁Speer en ▁für ▁Kalaschnikow s .
# PRED SCORE: -0.3890
#
# [2023-02-16 10:22:36,980 INFO]
# SENT 34032: ['▁Now', ',', '▁the', '▁true', '▁power', '▁of', '▁this', '▁technology', ',', '▁however', ',', '▁really', '▁comes', '▁from', '▁the', '▁fact', '▁that', '▁we', '▁can', '▁', '<unk>', '▁link', '▁them', '.']
# PRED 34032: ▁Die ▁wahre ▁Macht ▁dieser ▁Technologie ▁besteht ▁jedoch ▁aus ▁der ▁Tatsache , ▁dass ▁wir ▁ s trick s en ▁können .
# PRED SCORE: -0.6264
#
# [2023-02-16 10:22:36,981 INFO]
# SENT 34033: ['▁Then', '▁the', '▁pattern', ',', '▁head', '-', 'tail', '-', 'tail', ',', '▁that', '▁we', "'", 've', '▁suddenly', '▁become', '▁fixated', '▁with', '▁happens', '▁here', '.']
# PRED 34033: ▁Das ▁Muster , ▁Kopf - Zahl - Zahl ▁kommt ▁darauf ▁an , ▁dass ▁wir ▁uns ▁plötzlich ▁damit ▁beschäftigen .
# PRED SCORE: -0.4915
#
# [2023-02-16 10:22:36,981 INFO]
# SENT 34034: ['▁MM', ':', '▁Fellows', '▁are', '▁really', '▁good', '▁at', '▁that', '.', '▁(', 'Laugh', 's', ')', '▁(', 'Laughter', ')', '▁Okay', '.', '▁Now', '▁we', "'", 're', '▁going', '▁to', '▁switch', '▁back', '▁into', '▁the', '<unk>', '▁application', ',', '▁and', '▁what', '▁Tamara', "'", 's', '▁going', '▁to', '▁do', '▁is', '▁tag', '▁that', '▁video', '▁that', '▁we', '▁just', '▁took', '▁onto', '▁my', '▁badge', ',', '▁so', '▁that', '▁I', '▁can', '▁remember', '▁it', '▁forever', '.']
# PRED 34034: ▁MM : ▁Befürworter ▁sind ▁sehr ▁gut ▁darin . ▁( Lacht ) ▁( Lachen ) ▁Okay . ▁Jetzt ▁gehen ▁wir ▁zurück ▁in ▁die ▁ Elektrifizierung , ▁und ▁auch ▁das , ▁was ▁wir ▁tun ▁werden , ▁ist ▁der ▁Video , ▁den ▁wir ▁gerade ▁auf ▁meinen ▁Ausweis ▁nehmen , ▁so ▁dass ▁ich ▁ihn ▁für ▁immer ▁erinnern ▁kann .
# PRED SCORE: -0.5428
#
# [2023-02-16 10:22:36,981 INFO]
# SENT 34035: ['▁It', "'", 's', '▁a', '▁central', '▁document', '▁in', '▁Jewish', '▁history', '.']
# PRED 34035: ▁Es ▁ist ▁ein ▁zentrale s ▁Dokument ▁der ▁jüdische n ▁Geschichte .
# PRED SCORE: -0.2345
#
# [2023-02-16 10:22:36,981 INFO]
# SENT 34036: ['▁Now', ',', '▁by', '▁showing', '▁you', '▁some', '▁of', '▁these', '▁images', ',', '▁I', '▁hope', '▁that', '▁you', '▁will', '▁quickly', '▁see', '▁that', '▁galaxy', '▁clusters', '▁are', '▁these', '▁beautiful', '▁objects', ',', '▁but', '▁more', '▁than', '▁that', ',', '▁I', '▁think', '▁galaxy', '▁clusters', '▁are', '▁mysterious', ',', '▁they', '▁are', '▁surprising', ',', '▁and', '▁they', "'", 're', '▁useful', '.']
# PRED 34036: ▁In dem ▁ich ▁Ihnen ▁einige ▁dieser ▁Bilder ▁zeige , ▁hoffe ▁ich , ▁dass ▁Sie ▁schnell ▁sehen ▁werden , ▁dass ▁die ▁Galaxienhaufen ▁diese ▁schönen ▁Objekte ▁sind , ▁aber ▁mehr ▁als ▁das , ▁denke ▁ich , ▁Galaxien - Cluster ▁sind ▁mysteriös , ▁und ▁sie ▁sind ▁nützlich .
# PRED SCORE: -0.3636
#
# [2023-02-16 10:22:36,982 INFO]
# SENT 34037: ['▁You', '▁want', '▁to', '▁measure', '▁it', '▁by', '▁the', '▁time', '▁it', '▁took', '▁to', '▁reach', '▁maximum', '▁body', '▁size', '?']
# PRED 34037: ▁Man ▁will ▁sie ▁messen , ▁in dem ▁sie ▁die ▁maximale ▁Körper größe ▁erreicht ▁hat ?
# PRED SCORE: -0.5721
#
# [2023-02-16 10:22:36,982 INFO]
# SENT 34038: ['▁But', '▁if', '▁you', '▁banish', '▁the', '▁dragons', ',', '▁you', '▁banish', '▁the', '▁heroes', ',', '▁and', '▁we', '▁become', '▁attached', '▁to', '▁the', '▁heroic', '▁strain', '▁in', '▁our', '▁own', '▁lives', '.']
# PRED 34038: ▁Aber ▁wenn ▁wir ▁die ▁Drachen ▁schaffen , ▁dann ▁werden ▁Sie ▁die ▁Helden , ▁und ▁wir ▁werden ▁an ▁den ▁heldenhaften ▁Strang ▁in ▁unserem ▁Leben ▁gebunden .
# PRED SCORE: -0.6396
#
# [2023-02-16 10:22:36,982 INFO]
# SENT 34039: ['▁It', '▁takes', '▁a', '▁lot', '▁of', '▁weight', ',', '▁and', '▁it', '▁follows', '▁the', '▁classical', '▁design', '▁rules', '.']
# PRED 34039: ▁Es ▁nimmt ▁viel ▁Gewicht ▁und ▁folgt ▁den ▁klassischen ▁Entwurf sprinzipien .
# PRED SCORE: -0.4076
#
# [2023-02-16 10:22:36,982 INFO]
# SENT 34040: ['▁Mondragon', ',', '▁Spain', '▁is', '▁a', '▁community', '▁built', '▁entirely', '▁around', '▁worker', '▁cooperatives', '.']
# PRED 34040: ▁Mond rag ende ▁ist ▁eine ▁Gemeinschaft , ▁die ▁komplett ▁von ▁Arbeiter ▁umgeben ▁ist .
# PRED SCORE: -0.5234
#
# [2023-02-16 10:22:36,982 INFO]
# SENT 34041: ['▁I', '▁work', '▁from', '▁a', '▁similar', '▁position', '.']
# PRED 34041: ▁Ich ▁arbeite ▁aus ▁einer ▁ähnlich en ▁Position .
# PRED SCORE: -0.2154
#
# [2023-02-16 10:22:36,983 INFO]
# SENT 34042: ['▁If', '▁you', '▁have', '▁a', '▁', '9', '0', '▁percent', '▁target', ',', '▁everyone', '▁in', '▁the', '▁business', '▁finds', '▁a', '▁reason', '▁to', '▁be', '▁in', '▁the', '▁', '1', '0', '▁percent', '.']
# PRED 34042: ▁Wenn ▁man ▁ein ▁ 9 0 ▁Prozent ziel ▁hat , ▁findet ▁jeder ▁im ▁Geschäft ▁einen ▁Grund , ▁in ▁den ▁ 1 0 ▁Prozent ▁zu ▁sein .
# PRED SCORE: -0.4066
#
# [2023-02-16 10:22:36,983 INFO]
# SENT 34043: ['▁I', '▁like', '▁to', '▁create', '▁a', '▁timeline', '▁showing', '▁how', '▁the', '▁world', '▁came', '▁to', '▁be', '.']
# PRED 34043: ▁Ich ▁möchte ▁gerne ▁eine ▁Zeit leiste ▁finden , ▁die ▁zeigt , ▁wie ▁die ▁Welt ▁zu ▁sein ▁begann .
# PRED SCORE: -0.5197
#
# [2023-02-16 10:22:36,983 INFO]
# SENT 34044: ['▁It', '▁wasn', "'", 't', '▁like', '▁that', '▁in', '▁my', '▁day', ',', '▁but', '▁we', '▁still', '▁got', '▁very', '▁excited', '.']
# PRED 34044: ▁Das ▁war ▁nicht ▁so , ▁aber ▁wir ▁waren ▁noch ▁immer ▁begeistert .
# PRED SCORE: -0.4380
#
# [2023-02-16 10:22:36,983 INFO]
# SENT 34045: ['▁Steven', '▁Weinberg', ',', '▁the', '▁Nobel', '▁laureate', ',', '▁once', '▁said', ',', '▁"', 'The', '▁more', '▁the', '▁universe', '▁seems', '▁comprehensible', ',', '▁the', '▁more', '▁it', '▁seems', '▁pointless', '."']
# PRED 34045: ▁Steven ▁Weinberg , ▁der ▁ Nobelpreisträger in , ▁so bald ▁er ▁einmal ▁sagte : ▁" Das ▁Universum ▁scheint ▁verständlich , ▁je ▁mehr ▁es ▁für ▁ihn ▁bedeutet ."
# PRED SCORE: -0.4820
#
# [2023-02-16 10:22:36,983 INFO]
# SENT 34046: ['▁(', 'Spanish', ')', '▁And', '▁she', "'", 's', '▁still', '▁talking', '▁while', '▁she', '▁puts', '▁the', '▁car', '▁in', '▁park', ',', '▁hits', '▁the', '▁emergency', '▁brake', ',', '▁opens', '▁the', '▁door', ',', '▁and', '▁with', '▁a', '▁sp', 'ry', 'ness', '▁astounding', '▁in', '▁a', '▁woman', '▁her', '▁age', ',', '▁she', '▁jumps', '▁out', '▁of', '▁the', '▁car', ',', '▁knocks', '▁out', '▁the', '▁phone', '▁books', ',', '▁and', '▁then', '▁she', '▁walks', '▁around', '▁--', '▁she', "'", 's', '▁carrying', '▁her', '▁cheap', '▁K', 'mart', '▁purse', '▁with', '▁her', '▁--', '▁around', '▁the', '▁front', '▁of', '▁the', '▁car', '.']
# PRED 34046: ▁( Lachen ) ▁Und ▁sie ▁spricht ▁noch ▁immer , ▁während ▁sie ▁das ▁Auto ▁im ▁Park ▁legt , ▁auf ▁die ▁Not h ör f ung ▁trifft , ▁öffnet ▁die ▁Tür ▁und ▁erzählt ▁von ▁einer ▁Frau ▁in ▁ihrem ▁Alter ▁eine ▁Frau , ▁sie ▁springt ▁aus ▁dem ▁Auto , ▁heraus , ▁und ▁dann ▁läuft ▁sie ▁los ▁– ▁sie ▁trägt ▁ihre ▁billige ▁Tasche ▁mit ▁ihr ▁– ▁um ▁sie ▁herum ▁– ▁um ▁die ▁Ecke ▁des ▁Autos ▁herum .
# PRED SCORE: -0.5688
#
# [2023-02-16 10:22:36,984 INFO]
# SENT 34047: ['▁The', '▁iPatient', '▁is', '▁getting', '▁wonderful', '▁care', '▁all', '▁across', '▁America', '.']
# PRED 34047: ▁Der ▁i Patient ▁ist ▁eine ▁wunderbare ▁Pflege ▁überall ▁in ▁Amerika .
# PRED SCORE: -0.4021
#
# [2023-02-16 10:22:36,984 INFO]
# SENT 34048: ['▁The', '▁idea', '▁is', '▁that', '▁most', '▁of', '▁our', '▁technologies', '▁to', '▁explore', '▁the', '▁deep', '▁ocean', '▁come', '▁from', '▁oil', '▁and', '▁gas', '▁and', '▁military', ',', '▁who', ',', '▁you', '▁know', ',', '▁they', "'", 're', '▁not', '▁really', '▁caring', '▁to', '▁be', '▁gentle', '.']
# PRED 34048: ▁Die ▁Idee ▁ist , ▁dass ▁die ▁meisten ▁unserer ▁Technologien ▁den ▁Tiefsee ▁aus ▁ Ö l ▁und ▁Militär ▁kommen , ▁die , ▁wissen ▁Sie , ▁nicht ▁wirklich ▁bemüht ▁sind , ▁freundlich ▁zu ▁sein .
# PRED SCORE: -0.4284
#
# [2023-02-16 10:22:36,984 INFO]
# SENT 34049: ['▁I', '▁mean', ',', '▁everything', '▁off', ',', '▁it', "'", 's', '▁like', '▁the', '▁service', '▁call', '▁you', '▁get', '▁from', '▁the', '▁cable', '▁company', ',', '▁except', '▁for', '▁the', '▁whole', '▁world', '.']
# PRED 34049: ▁Ich ▁meine , ▁alles ▁ab , ▁es ▁ist ▁wie ▁der ▁Dienst , ▁den ▁Sie ▁aus ▁der ▁Kabel firma ▁bekommen , ▁außer ▁für ▁die ▁ganze ▁Welt .
# PRED SCORE: -0.4562
#
# [2023-02-16 10:22:36,984 INFO]
# SENT 34050: ['▁It', "'", 's', '▁gorgeous', '!']
# PRED 34050: ▁Es ▁ist ▁wunderschön !
# PRED SCORE: -0.1980
#
# [2023-02-16 10:22:36,984 INFO]
# SENT 34051: ['▁He', '▁volunteers', '.']
# PRED 34051: ▁Er ▁Freiwillige .
# PRED SCORE: -0.2087
#
# [2023-02-16 10:22:36,985 INFO]
# SENT 34052: ['▁But', '▁they', "'", 're', '▁necessary', ':', '▁they', "'", 're', '▁necessary', '▁to', '▁make', '▁that', '▁mathematics', '▁work', '.']
# PRED 34052: ▁Aber ▁sie ▁sind ▁notwendig : ▁Sie ▁müssen ▁diese ▁Mathematik ▁zur ▁Arbeit ▁bringen .
# PRED SCORE: -0.5020
#
# [2023-02-16 10:22:36,985 INFO]
# SENT 34053: ['▁Now', ',', '▁obviously', '▁this', '▁is', '▁not', '▁good', '▁news', ',', '▁but', '▁I', '▁think', '▁what', '▁this', '▁data', '▁also', '▁shows', '▁is', '▁that', '▁we', '▁could', '▁be', '▁doing', '▁a', '▁lot', '▁better', '.']
# PRED 34053: ▁Das ▁ist ▁natürlich ▁keine ▁gute ▁Nachricht , ▁aber ▁ich ▁denke , ▁diese ▁Daten ▁zeigen ▁auch , ▁dass ▁wir ▁viel ▁besser ▁machen ▁können .
# PRED SCORE: -0.3405
#
# [2023-02-16 10:22:36,985 INFO]
# SENT 34054: ['▁As', '▁you', '▁probably', '▁can', "'", 't', '▁see', '▁the', '▁detail', '▁here', ',', '▁but', '▁this', '▁is', '▁his', '▁report', '▁card', ',', '▁and', '▁you', "'", 'll', '▁see', ',', '▁he', "'", 's', '▁got', '▁perfect', '▁scores', '.']
# PRED 34054: ▁Wie ▁Sie ▁wahrscheinlich ▁die ▁Details ▁hier ▁nicht ▁sehen ▁können , ▁aber ▁das ▁ist ▁sein ▁Zeugnis . ▁Und ▁Sie ▁werden ▁sehen , ▁er ▁hat ▁perfekte ▁Punkte .
# PRED SCORE: -0.4359
#
# [2023-02-16 10:22:36,985 INFO]
# SENT 34055: ['▁And', '▁it', '▁reminded', '▁me', '▁that', '▁--', '▁to', '▁keep', '▁in', '▁the', '▁present', ',', '▁to', '▁look', '▁out', '▁for', '▁these', '▁kinds', '▁of', '▁things', '.']
# PRED 34055: ▁Und ▁es ▁erinnerte ▁mich ▁daran , ▁dass ▁ich ▁in ▁der ▁Gegenwart , ▁um ▁nach ▁diesen ▁Dingen ▁zu ▁suchen .
# PRED SCORE: -0.4797
#
# [2023-02-16 10:22:36,985 INFO]
# SENT 34056: ['▁We', "'", 're', '▁inside', '▁the', '▁Pike', '▁Place', '▁Market', '.']
# PRED 34056: ▁Wir ▁befinden ▁uns ▁in ▁den ▁Pik - Markt .
# PRED SCORE: -0.5010
#
# [2023-02-16 10:22:36,986 INFO]
# SENT 34057: ['▁Pascal', '▁has', '▁been', '▁called', '▁the', '▁architect', '▁of', '▁modern', '▁civilization', '.']
# PRED 34057: ▁Pascal ▁wurde ▁als ▁Architekt ▁der ▁moderne ▁Zivilisation ▁bezeichnet .
# PRED SCORE: -0.2406
#
# [2023-02-16 10:22:36,986 INFO]
# SENT 34058: ['▁The', '▁problem', '▁is', '▁this', '▁little', '▁three', '-', 'pound', '▁machine', '▁that', "'", 's', '▁behind', '▁your', '▁eyes', '▁and', '▁between', '▁your', '▁ears', '.']
# PRED 34058: ▁Das ▁Problem ▁ist , ▁dass ▁diese ▁kleine ▁ 3 ▁kg ▁schwere ▁Maschine ▁hinter ▁den ▁Augen ▁und ▁zwischen ▁den ▁Ohren ▁liegt .
# PRED SCORE: -0.4238
#
# [2023-02-16 10:22:37,525 INFO]
# SENT 34059: ['▁We', '▁spend', '▁so', '▁much', '▁time', '▁dismiss', 'ing', '▁ideas', '▁as', '▁democrat', '▁or', '▁republican', '.']
# PRED 34059: ▁Wir ▁verbringen ▁so ▁viel ▁Zeit ▁damit , ▁Ideen ▁als ▁Demokraten ▁oder ▁Demokraten ▁abtun .
# PRED SCORE: -0.2857
#
# [2023-02-16 10:22:37,525 INFO]
# SENT 34060: ['▁I', '▁think', '▁that', '▁social', '▁media', '▁is', '▁actually', '▁going', '▁to', '▁help', '▁us', '▁dismantle', '▁some', '▁of', '▁the', '▁silly', '▁and', '▁demean', 'ing', '▁stereotypes', '▁that', '▁we', '▁see', '▁in', '▁media', '▁and', '▁advertising', '▁about', '▁gender', '.']
# PRED 34060: ▁Ich ▁denke , ▁dass ▁soziale ▁Medien ▁uns ▁helfen ▁werden , ▁einige ▁der ▁albern en ▁und ▁verführerisch en ▁Stereotypen ▁zu ▁vernichten , ▁die ▁wir ▁in ▁den ▁Medien ▁und ▁in ▁der ▁Werbung ▁sehen .
# PRED SCORE: -0.5109
#
# [2023-02-16 10:22:37,526 INFO]
# SENT 34061: ['▁Chi', 'tra', '▁basically', '▁remixes', '▁and', '▁re', '-', 'titl', 'es', '▁these', '▁iconic', '▁images', '▁to', '▁tease', '▁out', '▁some', '▁of', '▁the', '▁sexual', '▁and', '▁gender', '▁politics', '▁embedded', '▁in', '▁these', '▁deeply', '▁influential', '▁comics', '.']
# PRED 34061: ▁Chi ne ▁Art ▁Mischung ▁aus ▁Chi n ▁besteht ▁im ▁Grunde ▁aus ▁diesen ▁ikonische n , ▁die ▁manche ▁der ▁sexuellen ▁und ▁Geschlechter rollen ▁in ▁der ▁Politik ▁in ▁diesen ▁stark ▁mächtig en ▁Comic - Comics ▁eingebettet ▁sind .
# PRED SCORE: -0.6594
#
# [2023-02-16 10:22:37,526 INFO]
# SENT 34062: ['▁Crying', '▁about', '▁corals', '▁is', '▁having', '▁a', '▁moment', ',', '▁guys', '.']
# PRED 34062: ▁Über ▁die ▁Korallen ▁gezogen ▁zu ▁werden , ▁Jungs .
# PRED SCORE: -0.7436
#
# [2023-02-16 10:22:37,526 INFO]
# SENT 34063: ['▁The', '▁glove', '▁has', '▁sensors', '▁to', '▁detect', '▁temperature', '▁and', '▁pressure', '▁and', '▁warn', '▁the', '▁user', '.']
# PRED 34063: ▁Der ▁Handschuh ▁hat ▁Sensoren , ▁Temperatur ▁und ▁Druck ▁aufzuspüren ▁und ▁die ▁Benutzer ▁zu ▁warnen .
# PRED SCORE: -0.4924
#
# [2023-02-16 10:22:37,527 INFO]
# SENT 34064: ['▁Then', '▁they', "'", 're', '▁comfortable', ',', '▁they', '▁have', '▁good', '▁vision', ',', '▁like', '▁this', '▁great', '▁big', '▁visor', '.']
# PRED 34064: ▁Dann ▁fühlen ▁sie ▁sich ▁wohl , ▁sie ▁haben ▁eine ▁gute ▁Vorstellung , ▁wie ▁dieser ▁große ▁Spa tz k ing le .
# PRED SCORE: -0.5963
#
# [2023-02-16 10:22:37,527 INFO]
# SENT 34065: ['▁So', ',', '▁it', '▁seemed', '▁that', '▁the', '▁toxin', '▁that', '▁was', '▁killing', '▁the', '▁gharial', '▁was', '▁something', '▁in', '▁the', '▁food', '▁chain', ',', '▁something', '▁in', '▁the', '▁fish', '▁they', '▁were', '▁eating', '.']
# PRED 34065: ▁Es ▁schien ▁also , ▁dass ▁das ▁Gift , ▁das ▁den ▁Gangesgavial ▁tötete , ▁etwas ▁in ▁der ▁Nahrungskette ▁war , ▁etwas ▁in ▁dem ▁Fisch , ▁den ▁sie ▁aßen .
# PRED SCORE: -0.3829
#
# [2023-02-16 10:22:37,527 INFO]
# SENT 34066: ['▁So', '▁we', '▁began', ',', '▁through', '▁our', '▁nonprofit', '▁institute', ',', '▁training', '▁hospitals', '▁around', '▁the', '▁country', ',', '▁and', '▁we', '▁found', '▁that', '▁most', '▁people', '▁could', '▁avoid', '▁surgery', '.']
# PRED 34066: ▁Also ▁begannen ▁wir , ▁durch ▁unsere ▁gemeinnützigen ▁Krankenhäuser ▁im ▁ganzen ▁Land , ▁und ▁wir ▁fanden ▁heraus , ▁dass ▁die ▁meisten ▁Leute ▁Operationen ▁vermeiden ▁können .
# PRED SCORE: -0.4084
#
# [2023-02-16 10:22:37,527 INFO]
# SENT 34067: ['▁It', '▁puts', '▁you', '▁into', '▁a', '▁proper', '▁relationship', '▁with', '▁reality', '.']
# PRED 34067: ▁Es ▁bringt ▁einen ▁in ▁eine ▁richtige ▁Beziehung ▁zu ▁der ▁Realität .
# PRED SCORE: -0.4807
#
# [2023-02-16 10:22:37,528 INFO]
# SENT 34068: ['▁That', "'", 's', '▁what', '▁a', '▁hydrophilic', '▁surface', '▁does', '.']
# PRED 34068: ▁Das ▁ist ▁es , ▁was ▁ hy drop hil les ▁Oberflächen wasser ▁leistet .
# PRED SCORE: -0.6039
#
# [2023-02-16 10:22:37,528 INFO]
# SENT 34069: ['▁South', '▁and', '▁North', '▁have', '▁been', '▁under', '▁arm', 'istic', 'e', '▁for', '▁', '6', '3', '▁years', ',', '▁since', '▁the', '▁end', '▁of', '▁the', '▁Korean', '▁War', '.']
# PRED 34069: ▁Seit ▁ 6 3 ▁Jahren ▁ist ▁Süd - ▁und ▁Nord staat lich ▁seit ▁dem ▁Ende ▁des ▁Koreakrieg s .
# PRED SCORE: -0.6453
#
# [2023-02-16 10:22:37,528 INFO]
# SENT 34070: ['▁However', ',', '▁this', '▁act', '▁of', '▁valor', '▁is', '▁ill', '▁conceived', '.']
# PRED 34070: ▁Diese ▁Art ▁der ▁Tugend ▁ist ▁jedoch ▁krank .
# PRED SCORE: -0.5421
#
# [2023-02-16 10:22:37,529 INFO]
# SENT 34071: ['▁All', '▁the', '▁weight', '▁of', '▁your', '▁upper', '▁torso', '▁--', '▁your', '▁arms', ',', '▁your', '▁head', '▁--', '▁goes', '▁right', '▁down', '▁through', '▁your', '▁back', ',', '▁your', '▁spine', ',', '▁into', '▁those', '▁bones', '▁when', '▁you', '▁sit', '.']
# PRED 34071: ▁Das ▁gesamte ▁Gewicht ▁des ▁Ober arm en ▁– ▁der ▁Arme , ▁der ▁Kopf ▁– ▁geht ▁direkt ▁durch ▁den ▁Rücken , ▁seine ▁Wirbelsäule , ▁in ▁die ▁Knochen , ▁wenn ▁Sie ▁sitzen .
# PRED SCORE: -0.4641
#
# [2023-02-16 10:22:37,529 INFO]
# SENT 34072: ['▁So', '▁it', '▁was', '▁sort', '▁of', '▁a', '▁spooky', '▁story', '.']
# PRED 34072: ▁Es ▁war ▁also ▁eine ▁irgendwie ▁unheimlich e ▁Geschichte .
# PRED SCORE: -0.4498
#
# [2023-02-16 10:22:37,529 INFO]
# SENT 34073: ['▁But', '▁this', '▁is', '▁how', '▁I', '▁get', '▁to', '▁that', '▁object', '.']
# PRED 34073: ▁Aber ▁so ▁komme ▁ich ▁zu ▁diesem ▁Objekt .
# PRED SCORE: -0.2440
#
# [2023-02-16 10:22:37,529 INFO]
# SENT 34074: ['▁In', '▁neuroscience', ',', '▁this', '▁is', '▁called', '▁the', '<unk>', '▁principle', ',', '▁neurons', '▁that', '▁fire', '▁together', '▁wire', '▁together', '.']
# PRED 34074: ▁In ▁der ▁Neuro wissenschaft ▁nennt ▁man ▁das ▁" Zeug ung s - Prinzip ". ▁Neuronen , ▁die ▁zusammen ▁mit ▁Draht ▁ zusammenarbeiten .
# PRED SCORE: -0.5933
#
# [2023-02-16 10:22:37,530 INFO]
# SENT 34075: ['▁No', ',', '▁what', '▁I', "'", 'm', '▁suggesting', '▁is', '▁that', '▁we', '▁should', '▁leap', '▁off', ',', '▁we', '▁should', '▁increase', '▁our', '▁velocity', '▁so', '▁it', "'", 's', '▁high', ',', '▁and', '▁we', '▁should', '▁leap', '▁off', '▁one', '▁side', '▁and', '▁go', '▁the', '▁other', '▁--', '▁of', '▁course', ',', '▁having', '▁calculated', '▁our', '▁differential', '▁equation', '▁very', '▁carefully', '.']
# PRED 34075: ▁Nein , ▁ich ▁schlage ▁vor , ▁dass ▁wir ▁unsere ▁Geschwindigkeit ▁erhöhen ▁sollten , ▁damit ▁es ▁hoch ▁ist , ▁und ▁wir ▁sollten ▁uns ▁von ▁einer ▁Seite ▁verabschieden ▁und ▁das ▁andere ▁tun ▁– ▁natürlich , ▁wenn ▁wir ▁unsere ▁Gleichung ▁sehr ▁vorsichtig ▁berechnet ▁haben .
# PRED SCORE: -0.5294
#
# [2023-02-16 10:22:37,530 INFO]
# SENT 34076: ['▁Now', '▁these', '▁are', '▁not', '▁robots', ',', '▁they', "'", 're', '▁kind', '▁of', '▁love', 'bots', ',', '▁you', '▁know', '.']
# PRED 34076: ▁Das ▁sind ▁keine ▁Roboter , ▁sondern ▁eher ▁Liebe s roboter .
# PRED SCORE: -0.5867
#
# [2023-02-16 10:22:37,530 INFO]
# SENT 34077: ['▁And', '▁I', '▁will', '▁mention', '▁that', '▁I', '▁actually', '▁developed', '▁temporal', '▁lobe', '▁seizures', '▁a', '▁number', '▁of', '▁years', '▁ago', ',', '▁but', '▁it', '▁was', '▁during', '▁the', '▁time', '▁I', '▁was', '▁writing', '▁my', '▁last', '▁book', ',', '▁and', '▁some', '▁people', '▁say', '▁that', '▁book', '▁is', '▁quite', '▁different', '.']
# PRED 34077: ▁Und ▁ich ▁werde ▁erwähnen , ▁dass ▁ich ▁vor ▁einigen ▁Jahren ▁Temporallappen de ▁Anfälle ▁entwickelt ▁habe , ▁aber ▁in ▁der ▁Zeit ▁als ▁ich ▁mein ▁letztes ▁Buch ▁schrieb , ▁und ▁einige ▁Leute ▁sagen , ▁dass ▁das ▁Buch ▁ganz ▁anders ▁ist .
# PRED SCORE: -0.5159
#
# [2023-02-16 10:22:37,531 INFO]
# SENT 34078: ['▁I', '▁need', '▁you', '▁to', '▁turn', '▁that', '▁piece', '▁of', '▁paper', '▁over', ';', '▁you', '▁should', '▁find', '▁that', '▁it', '’', 's', '▁blank', '▁on', '▁the', '▁other', '▁side', '.']
# PRED 34078: ▁Ich ▁muss ▁das ▁Stück ▁Papier ▁umdrehen . ▁Sie ▁sollten ▁feststellen , ▁dass ▁es ▁leer ▁auf ▁der ▁anderen ▁Seite ▁ist .
# PRED SCORE: -0.4902
#
# [2023-02-16 10:22:37,531 INFO]
# SENT 34079: ['▁She', '▁looked', '▁at', '▁thousands', '▁of', '▁cases', '▁of', '▁humans', '▁sharing', '▁watersheds', ',', '▁forestry', '▁resources', ',', '▁fisheries', ',', '▁and', '▁discovered', '▁that', '▁yes', ',', '▁in', '▁case', '▁after', '▁case', ',', '▁humans', '▁destroyed', '▁the', '▁commons', '▁that', '▁they', '▁depend', 'ed', '▁on', '.']
# PRED 34079: ▁Sie ▁sah ▁tausende ▁Fälle ▁von ▁Menschen , ▁die ▁sie ▁teilen , ▁Ressourcen , ▁Forst wesen , ▁und ▁fand ▁heraus , ▁dass ▁Menschen ▁nach ▁dem ▁Fall ▁das ▁Gemeingut ▁zerstörten .
# PRED SCORE: -0.6330
#
# [2023-02-16 10:22:37,531 INFO]
# SENT 34080: ['▁I', '▁said', ',', '▁"', 'No', ',', '▁use', '▁the', '▁method', '▁of', '▁the', '▁grandmother', '."']
# PRED 34080: ▁Ich ▁sagte : ▁" Nein , ▁nimm ▁die ▁Methode ▁der ▁Großmutter ."
# PRED SCORE: -0.2600
#
# [2023-02-16 10:22:37,531 INFO]
# SENT 34081: ['▁The', '▁victories', '▁of', '▁the', '▁New', '▁Deal', '▁didn', "'", 't', '▁happen', '▁just', '▁because', '▁suddenly', '▁everybody', '▁understood', '▁the', '▁brutal', 'ities', '▁of', '▁la', 'isse', 'z', '-', '<unk>', '.']
# PRED 34081: ▁Pat t ter ▁des ▁New ▁Deal s ▁passierte ▁nicht ▁nur , ▁weil ▁alle ▁auf ▁einmal ▁die ▁brutale ▁Lage ▁von ▁la kon s enz ▁kennen .
# PRED SCORE: -0.6729
#
# [2023-02-16 10:22:37,532 INFO]
# SENT 34082: ['▁(', 'Video', ')', '▁Isaac', '▁Mizrahi', ':', '▁We', "'", 're', '▁back', '▁on', '▁the', '▁set', '.', '▁Hi', ',', '▁Ben', '!']
# PRED 34082: ▁( Video ) ▁Isaac ▁Mizrahi : ▁Wir ▁sind ▁wieder ▁am ▁Anfang .
# PRED SCORE: -0.3933
#
# [2023-02-16 10:22:37,532 INFO]
# SENT 34083: ['▁End', '▁to', '▁end', ',', '▁that', '▁would', '▁form', '▁a', '▁line', '▁that', '▁would', '▁circle', '▁the', '▁earth', '▁twice', '.']
# PRED 34083: ▁Zum ▁Schluss ▁würde ▁das ▁eine ▁Linie ▁bilden , ▁die ▁die ▁Erde ▁zweimal ▁umkreisen ▁würde .
# PRED SCORE: -0.3676
#
# [2023-02-16 10:22:37,532 INFO]
# SENT 34084: ['▁As', '▁I', '▁was', '▁finishing', '▁my', '▁interview', '▁with', '▁the', '▁midwife', ',', '▁I', '▁noticed', '▁an', '▁area', '▁in', '▁her', '▁house', '▁that', '▁was', '▁decorated', '▁with', '▁elaborate', '▁homemade', '▁flags', '.']
# PRED 34084: ▁Als ▁ich ▁das ▁Interview ▁mit ▁der ▁Hebamme ▁fertig ▁war , ▁bemerkte ▁ich ▁einen ▁Bereich ▁in ▁ihrem ▁Haus , ▁der ▁mit hilfe ▁aggressiver ▁Flaggen ▁verziert ▁war .
# PRED SCORE: -0.5505
#
# [2023-02-16 10:22:37,532 INFO]
# SENT 34085: ['▁Design', '▁can', '▁fix', '▁this', '▁problem', '.']
# PRED 34085: ▁Design ▁kann ▁dieses ▁Problem ▁lösen .
# PRED SCORE: -0.1833
#
# [2023-02-16 10:22:37,533 INFO]
# SENT 34086: ['▁It', "'", 's', '▁really', '▁been', '▁a', '▁long', '▁time', '▁since', '▁we', "'", 've', '▁known', '▁about', '▁fusion', '.']
# PRED 34086: ▁Es ▁war ▁schon ▁lange ▁her , ▁seit ▁wir ▁über ▁die ▁Kernfusion ▁wissen .
# PRED SCORE: -0.4933
#
# [2023-02-16 10:22:37,533 INFO]
# SENT 34087: ['▁That', '▁could', '▁cost', '▁you', '▁a', '▁game', '.']
# PRED 34087: ▁Das ▁könnte ▁ein ▁Spiel ▁kosten .
# PRED SCORE: -0.3458
#
# [2023-02-16 10:22:37,533 INFO]
# SENT 34088: ['▁I', '▁am', '▁lesbian', '."']
# PRED 34088: ▁Ich ▁bin ▁lesbisch ."
# PRED SCORE: -0.1013
#
# [2023-02-16 10:22:38,479 INFO]
# SENT 34089: ['▁In', '▁AD', '▁', '9', '8', '4', '▁Vikings', '▁went', '▁out', '▁to', '▁Greenland', ',', '▁settled', '▁Greenland', ',', '▁and', '▁around', '▁', '1', '4', '5', '0', '▁they', '▁died', '▁out', '▁--', '▁the', '▁society', '▁collapsed', ',', '▁and', '▁every', '▁one', '▁of', '▁them', '▁ended', '▁up', '▁dead', '.']
# PRED 34089: ▁ 9 8 4 ▁liefen ▁die ▁Wikinger ▁nach ▁Grönland . ▁Sie ▁ließen ▁sich ▁von ▁ 1 4 5 0 ▁um ▁ 1 4 5 0 . ▁Die ▁Gesellschaft ▁kollabierte , ▁und ▁jede ▁einzelne ▁von ▁ihnen ▁wurde ▁tot .
# PRED SCORE: -0.5474
#
# [2023-02-16 10:22:38,480 INFO]
# SENT 34090: ['▁Co', 'nversely', ',', '▁in', '▁sports', '▁where', '<unk>', 've', '▁stature', '▁is', '▁an', '▁advantage', ',', '▁the', '▁small', '▁athletes', '▁got', '▁smaller', '.']
# PRED 34090: ▁Im ▁Sport ▁dagegen ▁ist ▁der ▁Vorteil ▁der ▁kleinen ▁Sportler ▁kleiner .
# PRED SCORE: -0.7775
#
# [2023-02-16 10:22:38,480 INFO]
# SENT 34091: ['▁The', '▁oceans', '▁have', '▁lost', '▁a', '▁lot', '▁of', '▁their', '▁productivity', '▁and', '▁we', "'", 're', '▁responsible', '▁for', '▁it', '.']
# PRED 34091: ▁Die ▁Ozeane ▁haben ▁eine ▁Menge ▁ihrer ▁Produktivität ▁verloren ▁und ▁wir ▁sind ▁dafür ▁verantwortlich .
# PRED SCORE: -0.2981
#
# [2023-02-16 10:22:38,481 INFO]
# SENT 34092: ['▁Instead', ',', '▁I', '▁was', '▁alarmed', '.']
# PRED 34092: ▁Stattdessen ▁war ▁ich ▁m ul m .
# PRED SCORE: -0.5450
#
# [2023-02-16 10:22:38,481 INFO]
# SENT 34093: ['▁At', '▁that', '▁time', ',', '▁there', '▁was', '▁only', '▁one', '▁bank', '▁that', '▁had', '▁ATMs', '▁in', '▁Kenya', ',', '▁and', '▁we', '▁could', '▁not', '▁get', '▁cash', '.', '▁The', '▁family', '▁couldn', "'", 't', '▁get', '▁cash', '▁for', '▁him', '▁to', '▁start', '▁the', '▁treatment', '▁until', '▁Monday', '.']
# PRED 34093: ▁Zu ▁dieser ▁Zeit ▁gab ▁es ▁nur ▁eine ▁Bank , ▁die ▁Bank ▁in ▁Kenia ▁hatte , ▁und ▁wir ▁konnten ▁keine ▁Geld ▁bekommen . ▁Die ▁Familie ▁konnte ▁ihn ▁nicht ▁für ▁ihn ▁bezahlen , ▁bis ▁Montag ▁zur ▁Behandlung .
# PRED SCORE: -0.4399
#
# [2023-02-16 10:22:38,482 INFO]
# SENT 34094: ['▁These', '▁were', '▁the', '▁men', '▁I', '▁called', '▁am', 'mu', ',', '▁which', '▁means', '▁uncle', '.']
# PRED 34094: ▁Das ▁waren ▁die ▁Männer , ▁die ▁ich ▁" No thing " ▁genannt ▁habe .
# PRED SCORE: -0.5280
#
# [2023-02-16 10:22:38,482 INFO]
# SENT 34095: ['▁Some', '▁of', '▁you', '▁might', '▁know', ',', '▁he', "'", 's', '▁a', '▁TEDster', '▁--', '▁Stephen', '▁Sagmeister', '▁and', '▁I', '▁are', '▁working', '▁on', '▁some', '▁layouts', '.', '▁And', '▁this', '▁is', '▁still', '▁in', '▁preliminary', '▁stages', ';', '▁these', '▁aren', "'", 't', '▁the', '▁final', 's', '.', '▁But', '▁these', '▁images', ',', '▁with', '▁Worldchanging', '.', 'com', ',', '▁can', '▁be', '▁placed', '▁into', '▁any', '▁kind', '▁of', '▁media', '.']
# PRED 34095: ▁Manche ▁von ▁Ihnen ▁wissen ▁vielleicht , ▁dass ▁er ▁ein ▁TEDster ▁ist ▁-- ▁Stephen ▁Sagmeister ▁und ▁ich ▁arbeiten ▁an ▁einer ▁I vis ier e . ▁Und ▁das ▁ist ▁noch ▁in ▁den ▁Phasen . ▁Das ▁sind ▁nicht ▁die ▁letzten ▁Endes . ▁Aber ▁diese ▁Bilder , ▁die ▁mit ▁jeder ▁Art ▁von ▁Medien ▁vermittelt ▁werden .
# PRED SCORE: -0.5885
#
# [2023-02-16 10:22:38,482 INFO]
# SENT 34096: ['▁(', 'Applause', ')', '▁Does', '▁talk', '▁of', '▁cur', 'ing', '▁climate', '▁change', '▁undermine', '▁the', '▁will', '▁to', '▁cut', '▁emissions', '?']
# PRED 34096: ▁( Applaus ) ▁Ver steht ▁es , ▁den ▁Klimawandel ▁zu ▁heilen , ▁der ▁die ▁Emissionen ▁reduzieren ▁soll ?
# PRED SCORE: -0.5004
#
# [2023-02-16 10:22:38,482 INFO]
# SENT 34097: ['▁And', '▁for', '▁at', '▁least', '▁one', '▁of', '▁them', ',', '▁there', '▁is', '▁a', '▁drug', '.']
# PRED 34097: ▁Und ▁für ▁mindestens ▁eine ▁von ▁ihnen ▁ist ▁ein ▁Medikament .
# PRED SCORE: -0.4206
#
# [2023-02-16 10:22:38,483 INFO]
# SENT 34098: ['▁I', "'", 've', '▁given', '▁a', '▁lot', '▁of', '▁children', "'", 's', '▁concerts', '▁for', '▁children', '▁of', '▁seven', '▁and', '▁eight', '▁years', '▁old', ',', '▁and', '▁whatever', '▁I', '▁play', ',', '▁whether', '▁it', "'", 's', '▁Bach', ',', '▁Beethoven', ',', '▁even', '▁Stock', 'hausen', ',', '▁or', '▁some', '▁jazz', 'y', '▁music', ',', '▁they', '▁are', '▁open', '▁to', '▁hear', '▁it', ',', '▁really', '▁willing', '▁to', '▁listen', ',', '▁and', '▁they', '▁are', '▁comfortable', '▁doing', '▁so', '.']
# PRED 34098: ▁Ich ▁habe ▁eine ▁Menge ▁Kinder ▁für ▁Kinder ▁von ▁sieben ▁und ▁acht ▁Jahren ▁aufgenommen , ▁und ▁egal ▁was ▁ich ▁spiele , ▁ob ▁es ▁Bach , ▁Beethoven , ▁überhaupt , ▁dabei ▁geht , ▁sich ▁dabei ▁rum k n ack en ▁oder ▁Jazz musik ▁zu ▁hören , ▁die ▁darauf ▁offen ▁sind , ▁zuzuhören , ▁und ▁sie ▁fühlen ▁sich ▁so ▁sicher .
# PRED SCORE: -0.6494
#
# [2023-02-16 10:22:38,483 INFO]
# SENT 34099: ['▁"', 'Fire', '▁runs', '▁through', '▁my', '▁body', '▁with', '▁the', '▁pain', '▁of', '▁loving', '▁you', '.']
# PRED 34099: ▁" Komm ▁durch ▁meinen ▁Körper , ▁mit ▁dem ▁Schmerz , ▁den ▁du ▁liebst .
# PRED SCORE: -0.4092
#
# [2023-02-16 10:22:38,483 INFO]
# SENT 34100: ['▁And', '▁what', "'", 's', '▁happened', ',', '▁over', '▁the', '▁last', '▁', '4', '0', '0', '▁years', '▁in', '▁particular', ',', '▁is', '▁that', '▁human', '▁beings', '▁have', '▁invented', '▁"', 'brain', 'lets', '"', '▁--', '▁little', '▁additional', '▁parts', '▁for', '▁our', '▁brain', '▁--', '▁made', '▁out', '▁of', '▁powerful', '▁ideas', '▁that', '▁help', '▁us', '▁see', '▁the', '▁world', '▁in', '▁different', '▁ways', '.']
# PRED 34100: ▁Und ▁was ▁passiert ▁ist , ▁in ▁den ▁letzten ▁ 4 0 0 ▁Jahren , ▁ist , ▁dass ▁Menschen ▁" Sch änder " ▁erfunden ▁haben ▁-- ▁kleine ▁zusätzliche ▁Teile ▁unseres ▁Gehirns ▁-- ▁aus ▁verschiedenen ▁Ideen , ▁die ▁uns ▁helfen , ▁die ▁Welt ▁auf ▁verschiedene ▁Weisen ▁zu ▁sehen .
# PRED SCORE: -0.4557
#
# [2023-02-16 10:22:38,484 INFO]
# SENT 34101: ['▁And', '▁then', '▁it', '▁has', '▁detectors', '▁on', '▁its', '▁back', '▁so', '▁it', '▁can', '▁sense', '▁how', '▁much', '▁starlight', '▁or', '▁moonlight', '▁is', '▁hitting', '▁its', '▁back', '.']
# PRED 34101: ▁Und ▁dann ▁hat ▁es ▁Detektoren ▁auf ▁seine ▁Rückseite , ▁so ▁dass ▁es ▁das ▁Sonnenlicht ▁oder ▁ein ▁Mond ▁wahrnehmen ▁kann , ▁in dem ▁er ▁seine ▁Rücken ▁trifft .
# PRED SCORE: -0.8788
#
# [2023-02-16 10:22:38,484 INFO]
# SENT 34102: ['▁I', '▁was', '▁doing', '▁graffiti', '▁--', '▁writing', '▁my', '▁name', '▁everywhere', ',', '▁using', '▁the', '▁city', '▁as', '▁a', '▁canvas', '.']
# PRED 34102: ▁Ich ▁machte ▁Graffiti ▁-- ▁schrieb ▁meinen ▁Namen ▁überall , ▁in dem ▁ich ▁die ▁Stadt ▁als ▁Leinwände ▁benutzte .
# PRED SCORE: -0.3265
#
# [2023-02-16 10:22:38,484 INFO]
# SENT 34103: ['▁We', '▁use', '▁rivers', '."']
# PRED 34103: ▁Wir ▁nutzen ▁Flüsse ."
# PRED SCORE: -0.2079
#
# [2023-02-16 10:22:38,485 INFO]
# SENT 34104: ['▁And', '▁it', '▁was', '▁about', '▁that', '▁time', '▁that', '▁I', '▁became', '▁so', '▁', 'smitten', '▁by', '▁these', '▁little', '▁cells', '▁that', '▁I', '▁redirected', '▁my', '▁entire', '▁lab', '▁to', '▁study', '▁them', '▁and', '▁nothing', '▁else', ',', '▁and', '▁my', '▁loyalty', '▁to', '▁them', '▁has', '▁really', '▁paid', '▁off', '.']
# PRED 34104: ▁Und ▁es ▁war ▁an ▁dieser ▁Zeit , ▁in ▁der ▁ich ▁diese ▁kleinen ▁Zellen ▁ab sch ür e , ▁die ▁ich ▁mein ▁ganze s ▁Labor ▁um ▁sie ▁zu ▁studieren ▁und ▁nichts ▁anderes , ▁und ▁meine ▁Loyalität ▁gegenüber ▁ihnen ▁hat ▁sich ▁wirklich ▁bezahlt .
# PRED SCORE: -0.5893
#
# [2023-02-16 10:22:38,485 INFO]
# SENT 34105: ['▁(', 'Music', ')', '▁Video', ':', '▁Narrator', ':', '▁By', '▁raising', '▁Bonobos', '▁in', '▁a', '▁culture', '▁that', '▁is', '▁both', '▁Bonobo', '▁and', '▁human', ',', '▁and', '▁documenting', '▁their', '▁development', '▁across', '▁two', '▁decades', ',', '▁scientists', '▁are', '▁exploring', '▁how', '▁cultural', '▁forces', '▁(', 'Laughter', ')', '▁may', '▁have', '▁operated', '▁during', '▁human', '▁evolution', '.']
# PRED 34105: ▁( Musik ) ▁Video : ▁Erzähler : ▁In dem ▁sie ▁Bonobos ▁in ▁einer ▁Kultur ▁erziehen , ▁die ▁sowohl ▁Bonobo ▁als ▁auch ▁Mensch ▁ist , ▁und ▁ihre ▁Entwicklung ▁über ▁zwei ▁Jahrzehnte ▁dokumentieren , ▁werden ▁Wissenschaftler ▁untersuchen , ▁wie ▁kulturelle ▁Kräfte ▁( Lachen ) ▁während ▁der ▁menschlichen ▁Evolution ▁eingesetzt ▁werden .
# PRED SCORE: -0.4515
#
# [2023-02-16 10:22:38,485 INFO]
# SENT 34106: ['▁You', '▁can', '▁see', '▁the', '▁step', '▁by', '▁step', '▁analysis', '▁that', '▁takes', '▁place', ',', '▁and', '▁as', '▁they', '▁build', '▁up', '▁their', '▁model', ',', '▁they', '▁move', '▁their', '▁nodes', '▁around', ',', '▁rearrang', 'ing', '▁them', '▁like', '▁Lego', '▁blocks', '.']
# PRED 34106: ▁Sie ▁sehen ▁den ▁Schritt ▁durch ▁Schritt analyse , ▁und ▁wenn ▁sie ▁ihre ▁Modell ▁erstellen , ▁bewegen ▁sie ▁ihre ▁Knoten ▁um ▁sich ▁herum , ▁um ▁sie ▁wie ▁Lego stein e ▁zu ▁ordnen .
# PRED SCORE: -0.5690
#
# [2023-02-16 10:22:38,486 INFO]
# SENT 34107: ['▁When', '▁people', '▁are', '▁hooked', '▁up', '▁to', '▁these', '▁machines', ',', '▁tasks', ',', '▁such', '▁as', '▁reading', '▁or', '▁doing', '▁math', '▁problems', ',', '▁each', '▁have', '▁corresponding', '▁areas', '▁of', '▁the', '▁brain', '▁where', '▁activity', '▁can', '▁be', '▁observed', '.']
# PRED 34107: ▁Wenn ▁Menschen ▁von ▁diesen ▁Maschinen ▁umgeben ▁sind , ▁wie ▁z . ▁B . ▁beim ▁Lesen ▁oder ▁in ▁Mathematik , ▁haben ▁jede ▁die ▁zugehörig en ▁Gehirnareale , ▁in ▁denen ▁Aktivität ▁flüchtig ▁sein ▁kann .
# PRED SCORE: -0.7034
#
# [2023-02-16 10:22:38,486 INFO]
# SENT 34108: ['▁William', '▁was', '▁really', '▁difficult', '▁to', '▁talk', '▁to', '.']
# PRED 34108: ▁William ▁war ▁schwer ▁zu ▁sprechen .
# PRED SCORE: -0.2090
#
# [2023-02-16 10:22:38,486 INFO]
# SENT 34109: ['▁In', '▁a', '▁democracy', ',', '▁power', '▁is', '▁supposed', '▁to', '▁reside', '▁with', '▁the', '▁people', ',', '▁period', '.']
# PRED 34109: ▁In ▁einer ▁Demokratie ▁liegt ▁Macht ▁in ▁den ▁Menschen , ▁Zeit .
# PRED SCORE: -0.4648
#
# [2023-02-16 10:22:38,487 INFO]
# SENT 34110: ['▁Of', '▁course', ',', '▁the', '▁criminal', '▁justice', '▁system', '▁treats', '▁them', '▁as', '▁common', '▁old', '▁garden', '▁criminals', '.']
# PRED 34110: ▁Natürlich ▁behandelt ▁das ▁ kriminellen ▁Justizsystem ▁so ▁wie ▁die ▁üblich en ▁alten ▁Garten s .
# PRED SCORE: -0.7533
#
# [2023-02-16 10:22:38,487 INFO]
# SENT 34111: ['▁It', "'", 's', '▁precious', ',', '▁and', '▁it', "'", 's', '▁really', '▁easy', '▁to', '▁lose', '.']
# PRED 34111: ▁Es ▁ist ▁kostbar ▁und ▁es ▁ist ▁leicht ▁zu ▁verlieren .
# PRED SCORE: -0.3378
#
# [2023-02-16 10:22:38,487 INFO]
# SENT 34112: ['▁Some', '▁of', '▁them', '▁made', '▁sense', '.', '▁Some', '▁of', '▁them', '▁didn', "'", 't', '.']
# PRED 34112: ▁Manche ▁von ▁ihnen ▁haben ▁Sinn ▁gemacht .
# PRED SCORE: -0.5093
#
# [2023-02-16 10:22:38,487 INFO]
# SENT 34113: ['▁And', '▁after', '▁that', '▁--', '▁I', '▁only', '▁worked', '▁one', '▁year', '▁--', '▁I', '▁said', ',', '▁"', 'That', "'", 's', '▁enough', '.', '▁One', '▁year', "'", 's', '▁enough', '▁for', '▁me', '▁to', '▁do', '▁that', '."']
# PRED 34113: ▁Und ▁danach ▁– ▁ich ▁arbeitete ▁nur ▁ein ▁Jahr ▁– ▁ich ▁sagte : ▁" Das ▁reicht ▁aus . ▁Ein ▁Jahr ▁ist ▁genug ▁für ▁mich , ▁das ▁zu ▁tun ."
# PRED SCORE: -0.3766
#
# [2023-02-16 10:22:38,488 INFO]
# SENT 34114: ['▁The', '▁second', '▁explanation', '▁is', '▁that', '▁in', '▁many', '▁times', '▁and', '▁places', ',', '▁there', '▁is', '▁a', '▁widespread', '▁sentiment', '▁that', '▁life', '▁is', '▁cheap', '.']
# PRED 34114: ▁Die ▁zweite ▁Erklärung ▁ist , ▁dass ▁es ▁in ▁vielen ▁Fällen ▁und ▁Orten ▁eine ▁weit ▁verbreitet e ▁Vorstellung ▁gibt , ▁dass ▁das ▁Leben ▁billig ▁ist .
# PRED SCORE: -0.3272
#
# [2023-02-16 10:22:38,488 INFO]
# SENT 34115: ['▁And', '▁we', '▁get', '▁a', '▁lot', '▁of', '▁that', '.']
# PRED 34115: ▁Und ▁wir ▁bekommen ▁eine ▁Menge ▁davon .
# PRED SCORE: -0.3980
#
# [2023-02-16 10:22:38,488 INFO]
# SENT 34116: ['▁I', "'", 've', '▁spent', '▁the', '▁last', '▁', '1', '5', '▁years', '▁or', '▁so', '▁advising', '▁governments', '▁around', '▁the', '▁world', ',', '▁and', '▁in', '▁all', '▁of', '▁that', '▁time', '▁I', '▁have', '▁never', '▁once', '▁seen', '▁a', '▁single', '▁domestic', '▁policy', '▁issue', '▁that', '▁could', '▁not', '▁be', '▁more', '▁imaginatively', ',', '▁effectively', '▁and', '▁rapidly', '▁resolved', '▁than', '▁by', '▁treating', '▁it', '▁as', '▁an', '▁international', '▁problem', ',', '▁looking', '▁at', '▁the', '▁international', '▁context', ',', '▁compar', 'ing', '▁what', '▁others', '▁have', '▁done', ',', '▁bringing', '▁in', '▁others', ',', '▁working', '▁externally', '▁instead', '▁of', '▁working', '▁internally', '.']
# PRED 34116: ▁Ich ▁habe ▁die ▁letzten ▁ 1 5 ▁Jahre ▁damit ▁verbracht , ▁Regierungen ▁der ▁ganzen ▁Welt ▁zu ▁beraten , ▁und ▁in ▁all ▁dieser ▁Zeit ▁habe ▁ich ▁noch ▁nie ▁ein ▁einziges ▁nationale s ▁Problem ▁gesehen , ▁das ▁nicht ▁viel ▁besser ▁sein ▁könnte , ▁und ▁mich ▁schneller ▁als ▁ein ▁internationale s ▁Problem ▁löste , ▁das ▁sich ▁den ▁internationalen ▁Kontext ▁anschaut , ▁im ▁Vergleich ▁zu ▁dem , ▁was ▁andere ▁getan ▁haben , ▁mit ▁einander ▁statt ▁sich ▁selbst ▁zu ▁beschäftigen .
# PRED SCORE: -0.6109
#
# [2023-02-16 10:22:38,572 INFO]
# SENT 34117: ['▁With', '▁the', '▁demonstration', '▁of', '▁the', '▁Morton', '▁Ether', '▁', 'Inhale', 'r', '▁at', '▁the', '▁Mass', '.', '▁General', '▁in', '▁', '1', '8', '4', '7', ',', '▁a', '▁whole', '▁new', '▁era', '▁of', '▁surgery', '▁was', '▁us', 'hered', '▁in', '.']
# PRED 34117: ▁Mit ▁der ▁Demonstration ▁des ▁Purpur en ▁Tananger s : ▁An ▁der ▁Stelle ▁wurde ▁General ▁in ▁ 1 8 4 7 ▁eine ▁völlig ▁neue ▁Ära ▁der ▁Operation ▁ins ▁Leben ▁gerufen .
# PRED SCORE: -0.6193
#
# [2023-02-16 10:22:38,573 INFO]
# SENT 34118: ['▁', '[', '"', 'F', 'ailure', '▁to', '▁Detect', '▁Change', 's', '▁in', '▁Scenes', '"', '▁slide', ']', '▁This', '▁is', '▁Ron', '▁Ren', 'sink', "'", 's', '▁work', ',', '▁which', '▁was', '▁in', '▁some', '▁degree', '▁inspired', '▁by', '▁that', '▁suggestion', '▁right', '▁at', '▁the', '▁end', '▁of', '▁the', '▁book', '.']
# PRED 34118: ▁ [ " Un s vor wort er " ] ▁Zurück fallen de ▁Änderungen ▁im ▁Film ▁" Z wie men ' s ▁Arbeit , ▁die ▁von ▁diesem ▁Vorschlag ▁inspiriert ▁wurde , ▁am ▁Ende ▁des ▁Buch s .
# PRED SCORE: -0.7709
#
# [2023-02-16 10:22:39,423 INFO]
# SENT 34119: ['▁I', '▁see', '▁this', '▁plus', '▁sign', '.']
# PRED 34119: ▁Ich ▁sehe ▁dieses ▁Zeichen ▁plus .
# PRED SCORE: -0.4365
#
# [2023-02-16 10:22:39,424 INFO]
# SENT 34120: ['▁In', '▁this', '▁scan', '▁pass', ',', '▁in', '▁green', '▁here', ',', '▁are', '▁two', '-', 'year', '-', 'olds', '▁with', '▁autism', '.']
# PRED 34120: ▁In ▁diesem ▁Scan , ▁hier ▁in ▁grün , ▁sind ▁es ▁zwei jährige ▁mit ▁Autismus .
# PRED SCORE: -0.3874
#
# [2023-02-16 10:22:39,424 INFO]
# SENT 34121: ['▁I', '▁also', '▁feared', '▁that', '▁this', '▁investment', '▁would', '▁be', '▁in', '▁vain', '.']
# PRED 34121: ▁Ich ▁fürchtete ▁auch , ▁dass ▁diese ▁Investitionen ▁in ▁die ▁Hand ▁gehen ▁würden .
# PRED SCORE: -0.4649
#
# [2023-02-16 10:22:39,424 INFO]
# SENT 34122: ['▁What', '▁is', '▁the', '▁lesson', '▁from', '▁all', '▁of', '▁this', '?']
# PRED 34122: ▁Was ▁ist ▁die ▁Lektion ▁von ▁all ▁dem ?
# PRED SCORE: -0.3256
#
# [2023-02-16 10:22:39,424 INFO]
# SENT 34123: ['▁And', '▁we', '▁see', '▁these', '▁families', ',', '▁these', '▁nomadic', '▁families', ',', '▁you', '▁know', ',', '▁father', '▁to', '▁son', ',', '▁father', '▁to', '▁son', ',', '▁and', '▁these', '▁guys', '▁are', '▁hurting', '.']
# PRED 34123: ▁Und ▁wir ▁sehen ▁diese ▁Familien , ▁diese ▁nomadische n ▁Familien , ▁wissen ▁Sie , ▁der ▁Vater ▁zum ▁Sohn , ▁und ▁diese ▁Jungs ▁tun ▁weh .
# PRED SCORE: -0.4553
#
# [2023-02-16 10:22:39,425 INFO]
# ...
# PRED SCORE: -0.8228
#
# [2023-02-16 10:22:59,943 INFO]
# SENT 34961: ['▁And', '▁one', '▁day', '▁--', '▁I', '▁don', "'", 't', '▁know', '▁what', '▁happened', '▁--', '▁while', '▁coming', '▁back', '▁from', '▁the', '▁office', '▁towards', '▁home', ',', '▁maybe', '▁I', '▁saw', '▁a', '▁honey', '▁bee', '▁or', '▁it', '▁occurred', '▁to', '▁my', '▁mind', '▁that', '▁if', '▁I', '▁only', '▁could', '▁be', '▁like', '▁the', '▁honey', '▁bee', ',', '▁life', '▁would', '▁be', '▁wonderful', '.']
# PRED 34961: ▁Eines ▁Tages ▁-- ▁ich ▁weiß ▁nicht , ▁was ▁passierte ▁-- ▁während ▁ich ▁vom ▁Büro ▁nach ▁Hause ▁kam , ▁sah ▁ich ▁vielleicht ▁einen ▁Honig , ▁oder ▁es ▁kam ▁mir ▁in ▁den ▁Sinn , ▁dass , ▁wenn ▁ich ▁nur ▁wie ▁der ▁Honig ▁wäre , ▁dann ▁wäre ▁das ▁Leben ▁wunderbar .
# PRED SCORE: -0.4592
#
# [2023-02-16 10:22:59,943 INFO]
# SENT 34962: ['▁Bring', 'ing', '▁people', ',', '▁future', '▁generations', ',', '▁together', '▁through', '▁Arabic', '▁calligraphy', '▁is', '▁what', '▁I', '▁do', '.']
# PRED 34962: ▁Menschen ▁zu ▁inspirieren , ▁zukünftige ▁Generationen , ▁durch ▁die ▁arabische ▁Botschaft , ▁was ▁ich ▁tue .
# PRED SCORE: -0.4643
#
# [2023-02-16 10:22:59,944 INFO]
# SENT 34963: ['▁Now', ',', '▁the', '▁stuntman', '▁solution', '▁to', '▁this', '▁in', '▁the', '▁old', '▁days', '▁would', '▁be', ',', '▁"', 'Let', "'", 's', '▁hit', '▁this', '▁as', '▁fast', '▁as', '▁possible', '.', '▁', '6', '0', '▁miles', '▁an', '▁hour', '.']
# PRED 34963: ▁Der ▁Stuntman ▁könnte ▁dies ▁in ▁den ▁alten ▁Tagen ▁sagen : ▁" Lasst ▁uns ▁das ▁so ▁schnell ▁wie ▁möglich ▁machen . ▁ 6 0 ▁Kilometer ▁pro ▁Stunde .
# PRED SCORE: -0.5105
#
# [2023-02-16 10:22:59,944 INFO]
# SENT 34964: ['▁Ninety', '-', 'eight', '▁percent', '▁of', '▁people', '▁really', '▁thought', '▁this', '▁just', '▁should', '▁have', '▁been', '▁normal', '▁practice', ',', '▁and', '▁that', '▁this', '▁is', '▁how', '▁things', '▁should', '▁work', '.']
# PRED 34964: ▁ 9 8 ▁Prozent ▁der ▁Leute ▁dachten , ▁dass ▁das ▁nur ▁normale ▁Praktiken ▁gewesen ▁wäre ▁und ▁dass ▁so ▁etwas ▁funktionieren ▁sollte .
# PRED SCORE: -0.4652
#
# [2023-02-16 10:22:59,944 INFO]
# SENT 34965: ['▁And', '▁here', '▁is', '▁a', '▁starfish', '▁and', '▁a', '▁cymatic', '▁starfish', '.']
# PRED 34965: ▁Und ▁hier ▁ist ▁ein ▁Seestern ▁und ▁ein ▁ cy tier .
# PRED SCORE: -0.4415
#
# [2023-02-16 10:22:59,944 INFO]
# SENT 34966: ['▁Over', 'night', ',', '▁my', '▁inbox', '▁morphed', '▁into', '▁this', '▁harbor', '▁of', '▁heartbreak', '▁--', '▁a', '▁single', '▁mother', '▁in', '▁Sacramento', ',', '▁a', '▁girl', '▁being', '▁bullied', '▁in', '▁rural', '▁Kansas', ',', '▁all', '▁asking', '▁me', ',', '▁a', '▁', '2', '2', '-', 'year', '-', 'old', '▁girl', '▁who', '▁bare', 'ly', '▁even', '▁knew', '▁her', '▁own', '▁coffee', '▁order', ',', '▁to', '▁write', '▁them', '▁a', '▁love', '▁letter', '▁and', '▁give', '▁them', '▁a', '▁reason', '▁to', '▁wait', '▁by', '▁the', '▁mailbox', '.']
# PRED 34966: ▁Über ▁Nacht ▁hatte ▁mein ▁Email ▁in ▁diesen ▁Hafen ▁von ▁Liebeskummer ▁-- ▁eine ▁einzige ▁Mutter ▁in ▁Sacramento , ▁ein ▁Mädchen , ▁das ▁ich ▁in ▁Kansas ▁unterrichtet ▁hatte , ▁ein ▁ 2 2 - jähriges ▁Mädchen , ▁das ▁kaum ▁ihre ▁eigene ▁Kaffee ▁kannte , ▁um ▁ihnen ▁einen ▁Liebesbrief ▁zu ▁schreiben ▁und ▁ihnen ▁einen ▁Grund ▁zu ▁geben , ▁dass ▁sie ▁am ▁Briefkasten ▁warten .
# PRED SCORE: -0.5208
#
# [2023-02-16 10:22:59,945 INFO]
# SENT 34967: ['▁So', '▁the', '▁challenge', '▁for', '▁me', '▁was', '▁to', '▁design', '▁type', '▁that', '▁performed', '▁as', '▁well', '▁as', '▁possible', '▁in', '▁these', '▁very', '▁adverse', '▁production', '▁conditions', '.']
# PRED 34967: ▁Die ▁Herausforderung ▁für ▁mich ▁war ▁es , ▁eine ▁Art ▁Design ▁zu ▁schaffen , ▁die ▁sowohl ▁unter ▁als ▁auch ▁möglich ▁ist , ▁die ▁Produktion sbedingungen ▁zu ▁verringern .
# PRED SCORE: -0.6085
#
# [2023-02-16 10:22:59,945 INFO]
# SENT 34968: ['▁But', '▁perhaps', '▁most', '▁exciting', '▁of', '▁all', '▁were', '▁the', '▁number', '▁of', '▁world', '▁leaders', '▁and', '▁elect', '▁politicians', '▁that', '▁were', '▁emerging', '▁from', '▁the', '▁documents', '▁--', '▁figures', '▁like', '<unk>', '▁Por', 'o', '<unk>', '▁in', '▁Ukraine', ',', '▁close', '▁associates', '▁of', '▁Vladimir', '▁Putin', '▁in', '▁Russia', '▁and', '▁the', '▁British', '▁Prime', '▁Minister', ',', '▁David', '▁Cameron', ',', '▁who', '▁is', '▁linked', '▁through', '▁his', '▁late', '▁father', ',', '▁I', 'an', '▁Cameron', '.']
# PRED 34968: ▁Aber ▁vielleicht ▁am ▁aufregendste n ▁waren ▁die ▁Zahl ▁der ▁weltweiten ▁Führer ▁und ▁die ▁Politiker , ▁die ▁aus ▁den ▁Dokumenten ▁kamen , ▁wie ▁z . ▁B . ▁Qu erschnittgelähmt er ▁machen , ▁nahe ▁stehenden ▁Menschen ▁in ▁Russland ▁und ▁der ▁britische n ▁Premierminister , ▁David ▁Cameron , ▁der ▁mit ▁ seinem ▁verstorbenen ▁Vater ▁verbunden ▁ist , ▁ich ▁Cameron .
# PRED SCORE: -0.4980
#
# [2023-02-16 10:22:59,945 INFO]
# SENT 34969: ['▁It', '▁has', '▁just', '▁the', '▁right', '▁value', '▁to', '▁keep', '▁the', '▁universe', '▁hanging', '▁in', '▁an', '▁unstable', '▁situation', '.']
# PRED 34969: ▁Es ▁hat ▁nur ▁den ▁richtig en ▁Wert , ▁das ▁Universum ▁in ▁einer ▁instabil en ▁Situation ▁zu ▁halten .
# PRED SCORE: -0.2290
#
# [2023-02-16 10:22:59,945 INFO]
# SENT 34970: ['▁In', '▁the', '▁remain', 'der', '▁of', '▁the', '<unk>', ',', '▁Lorenzetti', '▁shows', '▁us', '▁the', '▁inevitable', '▁effects', '▁of', '▁bad', '▁government', '.']
# PRED 34970: ▁In ▁der ▁restliche n ▁Zeit ▁zeigt ▁Lorenzetti ▁die ▁unvermeidlich e ▁Effekte ▁der ▁schlechten ▁Regierung .
# PRED SCORE: -0.6187
#
# [2023-02-16 10:22:59,945 INFO]
# SENT 34971: ['▁Some', '▁of', '▁us', '▁may', '▁have', '▁been', '▁sublimated', ',', '▁but', '▁really', '▁none', '▁of', '▁us', '▁remained', '▁the', '▁same', '.']
# PRED 34971: ▁Manche ▁von ▁uns ▁haben ▁vielleicht ▁gehört , ▁aber ▁keiner ▁von ▁uns ▁blieb ▁gleich .
# PRED SCORE: -0.6178
#
# [2023-02-16 10:22:59,946 INFO]
# SENT 34972: ['▁Because', '▁how', '▁we', '▁deal', '▁with', '▁our', '▁inner', '▁world', '▁drives', '▁everything', '.']
# PRED 34972: ▁Denn ▁wie ▁wir ▁mit ▁unserer ▁inneren ▁Welt ▁umgehen , ▁treibt ▁alles ▁an .
# PRED SCORE: -0.1979
#
# [2023-02-16 10:22:59,946 INFO]
# SENT 34973: ['▁It', '▁seems', '▁too', '▁daunting', ',', '▁too', '▁dangerous', ',', '▁for', '▁any', '▁company', '▁to', '▁take', '▁on', '.']
# PRED 34973: ▁Es ▁scheint ▁zu ▁entmutigend , ▁zu ▁gefährlich , ▁für ▁jede ▁Firma , ▁die ▁sich ▁annehmen ▁muss .
# PRED SCORE: -0.5664
#
# [2023-02-16 10:22:59,946 INFO]
# SENT 34974: ['▁But', '▁who', '▁is', '▁going', '▁to', '▁want', '▁to', '▁plug', '▁them', '▁in', '?']
# PRED 34974: ▁Aber ▁wer ▁will ▁sie ▁dazu ▁bringen ?
# PRED SCORE: -0.4812
#
# [2023-02-16 10:22:59,946 INFO]
# SENT 34975: ['▁This', '▁is', '▁Rachel', '▁Field', ',', '▁Robert', '▁Grave', 's', '▁--', '▁a', '▁very', '▁young', '▁Robert', '▁Grave', 's', '▁--', '▁Christina', '▁Ross', 'etti', '.']
# PRED 34975: ▁Das ▁ist ▁Rachel feld , ▁Robert ▁Sta e ▁-- ▁ein ▁sehr ▁junger ▁Robert ▁Grav es ▁-- ▁The ▁Ross y .
# PRED SCORE: -0.7043
#
# [2023-02-16 10:22:59,946 INFO]
# SENT 34976: ['▁You', '▁can', '▁get', '▁more', '▁bang', '▁for', '▁your', '▁buck', ',', '▁let', "'", 's', '▁say', '.']
# PRED 34976: ▁Sie ▁können ▁mehr ▁Knall ▁für ▁Ihr ▁Geld ▁bekommen , ▁sagen ▁wir .
# PRED SCORE: -0.6057
#
# [2023-02-16 10:22:59,947 INFO]
# SENT 34977: ['▁I', "'", 've', '▁been', '▁involved', '▁in', '▁global', '▁warming', '▁policy', '▁since', '▁', '1', '9', '9', '4', ',', '▁when', '▁I', '▁joined', '▁the', '▁board', '▁of', '▁Environmental', '▁Defense', '▁Fund', '▁that', '▁was', '▁one', '▁of', '▁the', '▁crafter', 's', '▁of', '▁the', '▁Kyoto', '▁Protocol', '.']
# PRED 34977: ▁Seit ▁ 1 9 9 4 ▁war ▁ich ▁an ▁der ▁globalen ▁Erwärmung ▁beteiligt , ▁als ▁ich ▁an ▁der ▁Tafel ▁des ▁Umwelt einfluss s ▁beteiligt ▁war , ▁der ▁eine ▁der ▁gebildet en ▁Allianz ▁des ▁Kyoto - Protokoll s ▁war .
# PRED SCORE: -0.5714
#
# [2023-02-16 10:22:59,947 INFO]
# SENT 34978: ['▁So', '▁if', '▁you', "'", 've', '▁been', '▁gone', ',', '▁this', '▁is', '▁the', '▁Cliff', 's', 'Note', 's', '▁on', '▁what', "'", 's', '▁happened', '▁in', '▁the', '▁economy', '.']
# PRED 34978: ▁Also , ▁wenn ▁Sie ▁weg ▁sind , ▁dies ▁ist ▁der ▁Cliff ord , ▁an ▁dem , ▁was ▁in ▁der ▁Wirtschaft ▁passiert ▁ist .
# PRED SCORE: -0.5651
#
# [2023-02-16 10:22:59,947 INFO]
# SENT 34979: ['▁So', '▁the', '▁question', '▁is', ':', '▁is', '▁that', '▁chemical', '▁phenomenon', '▁universal', ',', '▁or', '▁is', '▁it', '▁something', '▁which', '▁depends', '▁on', '▁the', '▁planet', '?']
# PRED 34979: ▁Die ▁Frage ▁ist ▁also : ▁Ist ▁das ▁chemische ▁Phänomen ▁universell , ▁oder ▁ist ▁es ▁etwas , ▁das ▁vom ▁Planeten ▁abhängt ?
# PRED SCORE: -0.3695
#
# [2023-02-16 10:22:59,947 INFO]
# SENT 34980: ['▁D', 'espite', '▁the', '▁idea', '▁that', '▁I', '▁love', '▁a', '▁good', '▁time', ',', '▁which', '▁I', '▁was', '▁rather', '▁amazed', '▁to', '▁see', '▁coming', '▁up', '▁on', '▁me', '▁--', '▁I', '▁actually', '▁spend', '▁a', '▁great', '▁deal', '▁of', '▁time', '▁alone', ',', '▁studying', ',', '▁and', '▁I', "'", 'm', '▁not', '▁very', '▁--', '▁you', "'", 're', '▁the', '▁people', '▁with', '▁media', '▁knowledge', '▁to', '▁explain', '▁to', '▁me', '▁how', '▁we', '▁can', '▁get', '▁this', '▁to', '▁everybody', ',', '▁everybody', '▁on', '▁the', '▁planet', '.', '▁I', "'", 've', '▁had', '▁some', '▁preliminary', '▁talks', ',', '▁and', '▁Arch', 'bishop', '▁Des', 'mond', '▁Tutu', ',', '▁for', '▁example', ',', '▁is', '▁very', '▁happy', '▁to', '▁give', '▁his', '▁name', '▁to', '▁this', ',', '▁as', '▁is', '▁I', '<unk>', '▁Fe', 'is', 'al', '▁Rau', 'f', ',', '▁the', '▁I', '<unk>', '▁in', '▁New', '▁York', '▁City', '.']
# PRED 34980: ▁Trotz ▁der ▁Idee , ▁dass ▁ich ▁eine ▁gute ▁Zeit ▁liebe , ▁die ▁ich ▁ziemlich ▁überrascht ▁war , ▁auf ▁mich ▁zu ▁kommen ▁-- ▁Ich ▁verbrachte ▁wirklich ▁eine ▁große ▁Zeit ▁allein , ▁studierte , ▁studierte , ▁studierte ▁und ▁nicht ▁sehr ▁-- ▁Sie ▁sind ▁die ▁Leute ▁mit ▁Medien , ▁die ▁mir ▁das ▁Wissen ▁erklären ▁können , ▁wie ▁wir ▁das ▁jedem ▁auf ▁dem ▁Planeten ▁erreichen ▁können . ▁Ich ▁hatte ▁ein ▁paar ▁Vorträge ▁und ▁S ado ma din , ▁ein ▁sehr ▁gutes ▁Beispiel ▁für ▁seine ▁Namen , ▁ [ unklar ] .
# PRED SCORE: -0.6835
#
# [2023-02-16 10:22:59,948 INFO]
# SENT 34981: ['▁(', 'Laughter', ')', '▁And', '▁they', '▁said', ',', '▁"', 'Oh', '.']
# PRED 34981: ▁( Lachen ) ▁Und ▁sie ▁sagten : ▁" Oh .
# PRED SCORE: -0.2492
#
# [2023-02-16 10:22:59,948 INFO]
# SENT 34982: ['▁It', '▁sounds', '▁sort', '▁of', '▁like', '▁"', 't', 'w', 'eeeeee', 't', '."', '▁Like', '▁that', '.']
# PRED 34982: ▁Es ▁klingt ▁ungefähr ▁so ▁wie ▁" niedergeschlagen " ▁und ▁so .
# PRED SCORE: -0.6571
#
# [2023-02-16 10:22:59,948 INFO]
# SENT 34983: ['▁This', '▁is', '▁not', '▁on', '▁another', '▁planet', '.', '▁These', '▁are', '▁things', '▁that', '▁are', '▁hidden', '▁away', '▁on', '▁our', '▁planet', '.']
# PRED 34983: ▁Das ▁ist ▁nicht ▁auf ▁einem ▁anderen ▁Planeten . ▁Das ▁sind ▁Dinge , ▁die ▁auf ▁unserem ▁Planeten ▁versteckt ▁sind .
# PRED SCORE: -0.3249
#
# [2023-02-16 10:22:59,948 INFO]
# SENT 34984: ['▁And', '▁--', '▁(', 'Laughter', ')', '▁So', '▁I', '▁was', '▁getting', '▁pretty', '▁nervous', '▁and', ',', '▁you', '▁know', ',', '▁I', '▁didn', "'", 't', '▁know', '▁that', '▁Chris', '▁sits', '▁on', '▁the', '▁stage', ',', '▁and', '▁that', "'", 's', '▁more', '▁nerve', '-', 'racking', '.']
# PRED 34984: ▁Und ▁-- ▁( Lachen ) ▁Ich ▁wurde ▁also ▁ziemlich ▁nervös ▁und ▁ich ▁wusste ▁nicht , ▁dass ▁Chris ▁auf ▁der ▁Bühne ▁sitzt ▁und ▁das ▁ist ▁mehr ▁Nerven ▁ potenz .
# PRED SCORE: -0.3773
#
# [2023-02-16 10:22:59,948 INFO]
# SENT 34985: ['▁It', "'", 's', '▁incredibly', '▁important', '▁right', '▁now', '.']
# PRED 34985: ▁Es ▁ist ▁jetzt ▁unglaublich ▁wichtig .
# PRED SCORE: -0.4047
#
# [2023-02-16 10:22:59,948 INFO]
# SENT 34986: ['▁And', '▁my', '▁inspirations', '▁are', '▁very', '▁eclectic', '.']
# PRED 34986: ▁Und ▁meine ▁Voraussetzungen ▁sind ▁sehr ▁vielseitig .
# PRED SCORE: -0.5338
#
# [2023-02-16 10:22:59,949 INFO]
# SENT 34987: ['▁There', '▁were', '▁ecological', '▁revolutions', '▁on', '▁land', '▁and', '▁at', '▁sea', ',', '▁leading', '▁to', '▁the', '▁modern', '▁world', '.']
# PRED 34987: ▁Es ▁gab ▁ökologische ▁Revolutionen ▁auf ▁dem ▁Land ▁und ▁auf ▁dem ▁Meer , ▁die ▁zu ▁der ▁modernen ▁Welt ▁führen .
# PRED SCORE: -0.3391
#
# [2023-02-16 10:22:59,949 INFO]
# SENT 34988: ['▁(', 'Laughter', ')', '▁Thank', '▁you', '▁very', '▁much', '▁indeed', '.']
# PRED 34988: ▁( Lachen ) ▁Vielen ▁Dank .
# PRED SCORE: -0.3012
#
# [2023-02-16 10:23:00,283 INFO]
# SENT 34989: ['▁And', '▁the', '▁same', '▁for', '▁', '3', '0', '0', '▁and', '▁', '4', '0', '0', '▁and', '▁so', '▁on', '.']
# PRED 34989: ▁Dasselbe ▁gilt ▁für ▁ 3 0 0 ▁und ▁ 4 0 0 ▁und ▁so ▁weiter .
# PRED SCORE: -0.2378
#
# [2023-02-16 10:23:00,284 INFO]
# SENT 34990: ['▁(', 'Laughter', ')', '▁In', '▁addition', '▁to', '▁the', 'orizing', '▁on', '▁evolution', '▁in', '▁"', 'The', '▁Origin', '▁of', '▁Species', ',"', '▁Charles', '▁Darwin', '▁also', '▁wrote', '▁the', '▁facial', '▁feedback', '▁response', '▁theory', '.']
# PRED 34990: ▁( Gelächter ) ▁Zusätzlich ▁zu ▁der ▁Evolution ▁der ▁Evolution ▁in ▁" Die ▁Entstehung ▁der ▁Arten ", ▁schrieb ▁Charles ▁Darwin ▁auch ▁die ▁" G PS - Theorie .
# PRED SCORE: -0.4367
#
# [2023-02-16 10:23:00,284 INFO]
# SENT 34991: ['▁But', '▁I', '▁teach', '▁spoken', '-', 'word', '▁poetry', '▁because', '▁it', "'", 's', '▁accessible', '.']
# PRED 34991: ▁Aber ▁ich ▁lehre ▁gesprochene ▁Poesie , ▁weil ▁es ▁zugänglich ▁ist .
# PRED SCORE: -0.2964
#
# [2023-02-16 10:23:00,284 INFO]
# SENT 34992: ['▁And', '▁so', '▁here', "'", 's', '▁my', '▁concern', ':', '▁tech', '▁companies', '▁which', '▁shall', '▁remain', '▁nameless', '▁...']
# PRED 34992: ▁Und ▁hier ▁ist ▁meine ▁Sorge : ▁Tech - Unternehmen , ▁die ▁weiterhin ▁Namen ▁erhalten ▁werden . .
# PRED SCORE: -0.8145
#
# [2023-02-16 10:23:00,284 INFO]
# SENT 34993: ['▁I', '▁volunteered', '▁on', '▁election', '▁day', '▁to', '▁do', '▁exit', '▁polling', '.']
# PRED 34993: ▁Ich ▁arbeitete ▁an ▁Wahltag , ▁um ▁Wahl fragen ▁zu ▁können .
# PRED SCORE: -0.6530
#
# [2023-02-16 10:23:00,284 INFO]
# SENT 34994: ['▁That', '▁would', '▁be', '▁enough', '▁to', '▁power', '▁your', '▁cell', '▁phone', '.']
# PRED 34994: ▁Das ▁wäre ▁genug , ▁um ▁das ▁Handy ▁zu ▁versorgen .
# PRED SCORE: -0.3525
#
# [2023-02-16 10:23:00,285 INFO]
# SENT 34995: ['▁That', "'", 's', '▁how', '▁the', '▁system', "'", 's', '▁supposed', '▁to', '▁work', '.']
# PRED 34995: ▁So ▁sollte ▁das ▁System ▁funktionieren .
# PRED SCORE: -0.2071
#
# [2023-02-16 10:23:00,285 INFO]
# SENT 34996: ['▁We', '▁see', '▁curiosity', '▁in', '▁the', '▁young', '.']
# PRED 34996: ▁Wir ▁sehen ▁Neugierde ▁in ▁jungen ▁Jahren .
# PRED SCORE: -0.4049
#
# [2023-02-16 10:23:00,285 INFO]
# SENT 34997: ['▁It', '▁was', '▁the', '▁Editors', "'", '▁Choice', '▁in', '▁Science', ',', '▁which', '▁is', '▁a', '▁top', '▁science', '▁magazine', '.']
# PRED 34997: ▁Es ▁war ▁die ▁Antwort ▁in ▁Wissenschaft , ▁das ▁ist ▁ein ▁wissen schaftliches ▁Magazin .
# PRED SCORE: -0.5670
#
# [2023-02-16 10:23:00,285 INFO]
# SENT 34998: ['▁Trans', '▁people', ',', '▁especially', '▁trans', '▁and', '▁gender', '-', 'non', 'con', 'forming', '▁youth', '▁face', '▁additional', '▁challenges', '▁when', '▁access', 'ing', '▁pools', '▁and', '▁gyms', ',', '▁but', '▁also', '▁universities', ',', '▁hospitals', ',', '▁libraries', '.']
# PRED 34998: ▁Trans menschen , ▁besonders ▁Trans - ▁und ▁Geschlecht - An bau en ▁von ▁Jugendlichen , ▁denen ▁Zugang ▁zu ▁Schul - ▁und ▁Angel punkt en , ▁aber ▁auch ▁Universitäten , ▁Krankenhäuser , ▁Bibliotheken .
# PRED SCORE: -0.6883
#
# [2023-02-16 10:23:00,285 INFO]
# SENT 34999: ['▁There', "'", 's', '▁still', '▁time', '▁to', '▁nudge', '▁them', ',', '▁if', '▁we', '▁think', '▁about', '▁nudging', '▁them', '▁rather', '▁than', '▁just', '▁punish', 'ing', '▁them', '.']
# PRED 34999: ▁Es ▁gibt ▁immer ▁noch ▁Zeit , ▁sie ▁zu ▁ziehen , ▁wenn ▁wir ▁darüber ▁nachdenken , ▁sie ▁zu ▁statt ▁einfach ▁zu ▁bestrafen .
# PRED SCORE: -0.5188
#
# [2023-02-16 10:23:00,286 INFO]
# SENT 35000: ['▁When', '▁I', '▁was', '▁in', '▁college', ',', '▁my', '▁senior', '▁year', ',', '▁I', '▁took', '▁a', '▁course', '▁called', '▁European', '▁I', 'ntellectual', '▁History', '.']
# PRED 35000: ▁Als ▁ich ▁in ▁der ▁Uni ▁war , ▁nahm ▁ich ▁einen ▁Kurs ▁namens ▁europäische n ▁Intellektuelle .
# PRED SCORE: -0.6169
#
# [2023-02-16 10:23:00,291 INFO] PRED SCORE: -0.4508, PRED PPL: 1.57 NB SENTENCES: 35000

# %% [markdown]
# ## Checking the Translation File
#
# In case you deleted `-verbose` above, you can check the first 5 lines (or more if you change the value in the first line of code below) of your translation here. `translation` in the cell below refers to your translation file as saved during the step above. If you have changed the name of your translation file, this needs to be changed in the cell below as well. Otherwise, simply run the cell below to print the first 5 lines of your (subworded) translation (don't expect a DeepL-level translation quality; remember that we are training a very small model with a standard parameter set here). You can also re-load your Drive folder and the full translation file created above should have been saved there.

# %%
# !head -n 5 translation
# Out:
# ▁Aber ▁es ▁bleibt ▁so ▁viel ▁übrig , ▁von ▁den ▁anderen ▁ 9 , 9 ▁Prozent ▁der ▁Dinge ▁zu ▁lernen , ▁die ▁jemals ▁gelebt ▁haben .
# ▁Aber ▁mit ▁Hilfe ▁von ▁Technik ▁und ▁ Einfallsreichtum ▁wuchs ▁die ▁Vietnamesen ▁auf .
# ▁So ▁sehr ▁schnell ▁-- ▁ungefähr ▁sechs ▁Wochen ▁in ▁diese ▁Forschung ▁-- ▁Ich ▁habe ▁diese ▁komplett ▁b röcke lt er , ▁dass ▁ich ▁die ▁Verbindung ▁absolut ▁auf ▁eine ▁Art ▁und ▁Weise , ▁die ▁ich ▁nicht ▁verstand ▁oder ▁nie ▁hatte .
# ▁" Der ▁warme ▁Winde ▁können ▁dich ▁nicht ▁berühren ."
# ▁Amerikaner ▁erkannten ▁seine ▁Leistung ▁und ▁riefen ▁den ▁Pfad : ▁" Eine s ▁der ▁größten ▁ Errungenschaften ▁des ▁ 2 0 . ▁Jahrhunderts ."

# %% [markdown]
# # Desubwording your Translation
#
# Now you have to desubword your translation file for further evaluation. This will remove the underscores visible in the subworded translation output above and combine individual subwords such as *_v* and *erfassungswidrig* into full words such as *verfassungswidrig*. In order to desubword your translation, we need to take two important steps: 1. connect this notebook to the [DataLitMT Github Repository](https://github.com/ITMK/DataLitMT), and 2. refer to the **subword models** (specifically *target.model*) trained in the previous data preparation task. Check to see in which folder you have saved these models because you will need to access them here.
#
# **Note**: If you do not have the saved subword models available, scroll up to the beginning of this notebook to the *Optional – Accessing Data* section. You can download the TED data zip file which also contains the subword source and target models. You can upload the subworded target file into your Google Drive folder and then run the cells below. This step is also explained in the tutorial video.
#
# Let's first connect this notebook to the GitHub repository by simply running the code cell below.

# %%
# Connect to the DataLitMT GitHub
# !git clone https://github.com/ITMK/DataLitMT.git
# Out:
# Cloning into 'DataLitMT'...
# remote: Enumerating objects: 1019, done.
# remote: Counting objects: 100% (272/272), done.
# remote: Compressing objects: 100% (121/121), done.
# remote: Total 1019 (delta 182), reused 212 (delta 148), pack-reused 747
# Receiving objects: 100% (1019/1019), 30.78 MiB | 16.64 MiB/s, done.
# Resolving deltas: 100% (508/508), done.

# %% [markdown]
# Let's now install the latest version of [SentencePiece](https://aclanthology.org/D18-2012/) (a language-independent subword tokenizer and detokenizer for neural network-based text processing, such as NMT). Simply run the cell below.

# %%
# If needed install/update SentencePiece
# !pip3 install --upgrade -q sentencepiece
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 35.4 MB/s eta 0:00:00

# %% [markdown]
# If you know where you saved your **subword target.model** from the Data Planning and Collection task, you can desubword your translation. In the cell below, we need to access three files:
#
# 1. The desubwording python file from the DataLit<sup>MT</sup> GitHub repository accessed by `DataLitMT/data-preparation/desubword.py` (no need to change anything here),
# 2.   Your subword *target.model* (from the previous task) – if this is saved in a different folder, you need to change the cell below to `YOUR_FOLDER/target.model` to access it,
# 3.   The translation that you just created above – If you saved it under a different name, you need to change the name `translation` below.

# %%
# Desubword the translation file
# !python3 DataLitMT/learning_resources/data_planning_and_collection/desubword.py target.model translation
# Out:
# Done desubwording! Output: translation.desubword

# %% [markdown]
# The desubworded translation file will have been saved automatically to your working folder as `translation.desubworded`, so check your Drive folder for this file. Again, if you re-named your translation file, check for the file `your_name.desubworded`.
#
# You can also check the first 5 lines of the subworded file by running the cell below. If needed, change the name of your translation file.

# %%
# Check the first 5 lines of the desubworded translation file
# !head -n 5 translation.desubword
# Out:
# Aber es bleibt so viel übrig, von den anderen 9,9 Prozent der Dinge zu lernen, die jemals gelebt haben.
# Aber mit Hilfe von Technik und Einfallsreichtum wuchs die Vietnamesen auf.
# So sehr schnell -- ungefähr sechs Wochen in diese Forschung -- Ich habe diese komplett bröckelter, dass ich die Verbindung absolut auf eine Art und Weise, die ich nicht verstand oder nie hatte.
# "Der warme Winde können dich nicht berühren."
# Amerikaner erkannten seine Leistung und riefen den Pfad: "Eines der größten Errungenschaften des 20. Jahrhunderts."

# %% [markdown]
# Compare this desubworded translation output to the subworded translation output above to see which changes were made through this desubwording step.
#
# Now you can also **desubword the reference dataset**: the German test dataset you have split from the original dataset during the Data Planning and Collection task. It should be saved as `TED2020.de-en.de-filtered.de.subword.test` and can now be used as a reference against which you can compare the German translation.
#
# Reference data is needed to perform a manual or automatic quality evaluation of an NMT model by analysing the output by analysing the model output. Automatic quality evaluation is further explained in our respective [Basic Level](https://colab.research.google.com/drive/1UgsqgN-6yfDESU7Geei4RXzJShEQNViZ?usp=sharing
# ) and [Advanced Level](https://colab.research.google.com/drive/19a896dbRBVtJmqA6JIFBU7bUiASfAo6V?usp=sharing) notebooks.
#
# Note: If you have trained the NMT model from German to English or for a different language combination, make sure you refer to the correct test data as the reference below.

# %%
# Desubword the target file (reference) of the test dataset
# !python3 DataLitMT/learning_resources/data_planning_and_collection/desubword.py target.model TED2020.de-en.de-filtered.de.subword.test
# Out:
# Done desubwording! Output: TED2020.de-en.de-filtered.de.subword.test.desubword

# %% [markdown]
# Equally, the desubworded reference file should now have been saved automatically to your Drive folder as `TED2020.de-en.de-filtered.de.subword.test.desubworded` – Check your folder for this file. Of course, you can also change the name of this file if later you make sure to refer to the correct file names when, for example, calculating automatic quality scores for your translation output.
# Run the cell below to check the first 5 lines of the desubworded reference (test) set.

# %%
# Check the first 5 lines of the desubworded reference
# !head -n 5 TED2020.de-en.de-filtered.de.subword.test.desubword
# Out:
# Aber es gibt noch viele andere Quellen, z.B. die 99,9 Prozent der Lebewesen, die auf der Erde heimisch waren.
# Aber mit Baukunst und Einfallsreichtum wurde der Pfad erweitert und verbessert.
# Sehr bald -- bereits nach etwa sechs Wochen Forschung -- traf ich auf diese unbenannte Sache, die Verbindung gänzlich entschlüsselte, auf eine Weise, die ich nicht verstand oder nie zuvor gesehen hatte.
# "Die heißen Winde können dir nichts antun."
# Amerika erkannte diese Leistung und nannte es: "Die größte Leistung in militärischer Konstruktion im 20.

# %% [markdown]
# # Quick Evaluation
#
# In this section, we will calculate the **BLEU** score by [Papineni et al. (2002)](https://www.aclweb.org/anthology/P02-1040.pdf) in its **sacreBLEU implementation** ([Post 2018](https://aclanthology.org/W18-6319/)) (for the translation (`translation`) by referring to the reference data (the test dataset `TED2020.de-en.de-filtered.de.subword.test.desubworded`).
#
# For this, you will need to install the sacreBLEU package by simply running the cell below.

# %%
# Install and import (sacre)BLEU functions
# !pip install sacrebleu
import sacrebleu
from sacrebleu.metrics import BLEU

# %% [markdown]
# Now you can calculate the BLEU score for your translation by running the cell below. Once again, if you have changed the name of your files, please adapt the file names accordingly in the cell below.

# %%
# Calculate a sacreBLEU score for your translation
# !sacrebleu TED2020.de-en.de-filtered.de.subword.test.desubword -i translation.desubword -m bleu --score-only --width 2
# Out:
# 23.60

# %% [markdown]
# BLEU scores are interpreted on a scale between 0 and 100. The closer the score is to 100, the higher the quality of the translation. Again, don't expect a very high score here, as we've trained only a small NMT model using a standard parameter set.
#
# There is a range of automatic metrics, for MT quality evaluation. Have a look at our [notebook on automatic MT quality evaluation](https://colab.research.google.com/drive/19xcHt9oLcvcSLGOepayTOIO_wkSPSZmG?usp=sharing) for a more detailed introduction to the topic. You can also use the code in our quality evaluation notebook to calculate different scores for your translation output produced in the present notebook.

# %% [markdown]
# Congratulations! You have now successfully trained an NMT model from scratch using your previously prepared datasets, and you have created a translation using this NMT model. Finally, you have performed a quick quality evaluation by calculating a BLEU score for your translation output. Welcome to the MT community! 😀
